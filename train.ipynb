# %%
import os
import sys
import time
import random
import string
import argparse

import torch
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data
import numpy as np

from utils import CTCLabelConverter, CTCLabelConverterForBaiduWarpctc, AttnLabelConverter, Averager
from dataset import hierarchical_dataset, AlignCollate, Batch_Balanced_Dataset
from model import Model
from test import validation
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def train(opt):
    """ dataset preparation """
    if not opt.data_filtering_off:
        print('Filtering the images containing characters which are not in opt.character')
        print('Filtering the images whose label is longer than opt.batch_max_length')
        # see https://github.com/clovaai/deep-text-recognition-benchmark/blob/6593928855fb7abb999a99f428b3e4477d4ae356/dataset.py#L130

    opt.select_data = opt.select_data.split('-')
    opt.batch_ratio = opt.batch_ratio.split('-')
    train_dataset = Batch_Balanced_Dataset(opt)

    log = open(f'./saved_models/{opt.exp_name}/log_dataset.txt', 'a')
    AlignCollate_valid = AlignCollate(imgH=opt.imgH, imgW=opt.imgW, keep_ratio_with_pad=opt.PAD)
    valid_dataset, valid_dataset_log = hierarchical_dataset(root=opt.valid_data, opt=opt)
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=opt.batch_size,
        shuffle=True,  # 'True' to check training progress with validation function.
        num_workers=int(opt.workers),
        collate_fn=AlignCollate_valid, pin_memory=True)
    log.write(valid_dataset_log)
    print('-' * 80)
    log.write('-' * 80 + '\n')
    log.close()
    
    """ model configuration """
    if 'CTC' in opt.Prediction:
        if opt.baiduCTC:
            converter = CTCLabelConverterForBaiduWarpctc(opt.character)
        else:
            converter = CTCLabelConverter(opt.character)
    else:
        converter = AttnLabelConverter(opt.character)
    opt.num_class = len(converter.character)

    if opt.rgb:
        opt.input_channel = 3
    model = Model(opt)
    print('model input parameters', opt.imgH, opt.imgW, opt.num_fiducial, opt.input_channel, opt.output_channel,
          opt.hidden_size, opt.num_class, opt.batch_max_length, opt.Transformation, opt.FeatureExtraction,
          opt.SequenceModeling, opt.Prediction)

    # weight initialization
    for name, param in model.named_parameters():
        if 'localization_fc2' in name:
            print(f'Skip {name} as it is already initialized')
            continue
        try:
            if 'bias' in name:
                init.constant_(param, 0.0)
            elif 'weight' in name:
                init.kaiming_normal_(param)
        except Exception as e:  # for batchnorm.
            if 'weight' in name:
                param.data.fill_(1)
            continue

    # data parallel for multi-GPU
    model = torch.nn.DataParallel(model).to(device)
    model.train()
    if opt.saved_model != '':
        print(f'loading pretrained model from {opt.saved_model}')
        if opt.FT:
            model.load_state_dict(torch.load(opt.saved_model), strict=False)
        else:
            model.load_state_dict(torch.load(opt.saved_model))
    print("Model:")
    print(model)

    """ setup loss """
    if 'CTC' in opt.Prediction:
        if opt.baiduCTC:
            # need to install warpctc. see our guideline.
            from warpctc_pytorch import CTCLoss 
            criterion = CTCLoss()
        else:
            criterion = torch.nn.CTCLoss(zero_infinity=True).to(device)
    else:
        criterion = torch.nn.CrossEntropyLoss(ignore_index=0).to(device)  # ignore [GO] token = ignore index 0
    # loss averager
    loss_avg = Averager()

    # filter that only require gradient decent
    filtered_parameters = []
    params_num = []
    for p in filter(lambda p: p.requires_grad, model.parameters()):
        filtered_parameters.append(p)
        params_num.append(np.prod(p.size()))
    print('Trainable params num : ', sum(params_num))
    # [print(name, p.numel()) for name, p in filter(lambda p: p[1].requires_grad, model.named_parameters())]

    # setup optimizer
    if opt.adam:
        optimizer = optim.Adam(filtered_parameters, lr=opt.lr, betas=(opt.beta1, 0.999))
    else:
        optimizer = optim.Adadelta(filtered_parameters, lr=opt.lr, rho=opt.rho, eps=opt.eps)
    print("Optimizer:")
    print(optimizer)

    """ final options """
    # print(opt)
    with open(f'./saved_models/{opt.exp_name}/opt.txt', 'a') as opt_file:
        opt_log = '------------ Options -------------\n'
        args = vars(opt)
        for k, v in args.items():
            opt_log += f'{str(k)}: {str(v)}\n'
        opt_log += '---------------------------------------\n'
        print(opt_log)
        opt_file.write(opt_log)

    """ start training """
    start_iter = 0
    if opt.saved_model != '':
        try:
            start_iter = int(opt.saved_model.split('_')[-1].split('.')[0])
            print(f'continue to train, start_iter: {start_iter}')
        except:
            pass

    start_time = time.time()
    best_accuracy = -1
    best_norm_ED = -1
    iteration = start_iter

    while(True):
        # train part
        image_tensors, labels = train_dataset.get_batch()
        image = image_tensors.to(device)
        text, length = converter.encode(labels, batch_max_length=opt.batch_max_length)
        batch_size = image.size(0)

        if 'CTC' in opt.Prediction:
            preds = model(image, text)
            preds_size = torch.IntTensor([preds.size(1)] * batch_size)
            if opt.baiduCTC:
                preds = preds.permute(1, 0, 2)  # to use CTCLoss format
                cost = criterion(preds, text, preds_size, length) / batch_size
            else:
                preds = preds.log_softmax(2).permute(1, 0, 2)
                cost = criterion(preds, text, preds_size, length)

        else:
            preds = model(image, text[:, :-1])  # align with Attention.forward
            target = text[:, 1:]  # without [GO] Symbol
            cost = criterion(preds.view(-1, preds.shape[-1]), target.contiguous().view(-1))

        model.zero_grad()
        cost.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), opt.grad_clip)  # gradient clipping with 5 (Default)
        optimizer.step()

        loss_avg.add(cost)

        # validation part
        if (iteration + 1) % opt.valInterval == 0 or iteration == 0: # To see training progress, we also conduct validation when 'iteration == 0' 
            elapsed_time = time.time() - start_time
            # for log
            with open(f'./saved_models/{opt.exp_name}/log_train.txt', 'a') as log:
                model.eval()
                with torch.no_grad():
                    valid_loss, current_accuracy, current_norm_ED, preds, confidence_score, labels, infer_time, length_of_data = validation(
                        model, criterion, valid_loader, converter, opt)
                model.train()

                # training loss and validation loss
                loss_log = f'[{iteration+1}/{opt.num_iter}] Train loss: {loss_avg.val():0.5f}, Valid loss: {valid_loss:0.5f}, Elapsed_time: {elapsed_time:0.5f}'
                loss_avg.reset()

                current_model_log = f'{"Current_accuracy":17s}: {current_accuracy:0.3f}, {"Current_norm_ED":17s}: {current_norm_ED:0.2f}'

                # keep best accuracy model (on valid dataset)
                if current_accuracy > best_accuracy:
                    best_accuracy = current_accuracy
                    torch.save(model.state_dict(), f'./saved_models/{opt.exp_name}/best_accuracy.pth')
                if current_norm_ED > best_norm_ED:
                    best_norm_ED = current_norm_ED
                    torch.save(model.state_dict(), f'./saved_models/{opt.exp_name}/best_norm_ED.pth')
                best_model_log = f'{"Best_accuracy":17s}: {best_accuracy:0.3f}, {"Best_norm_ED":17s}: {best_norm_ED:0.2f}'

                loss_model_log = f'{loss_log}\n{current_model_log}\n{best_model_log}'
                print(loss_model_log)
                log.write(loss_model_log + '\n')

                # show some predicted results
                dashed_line = '-' * 80
                head = f'{"Ground Truth":25s} | {"Prediction":25s} | Confidence Score & T/F'
                predicted_result_log = f'{dashed_line}\n{head}\n{dashed_line}\n'
                for gt, pred, confidence in zip(labels[:5], preds[:5], confidence_score[:5]):
                    if 'Attn' in opt.Prediction:
                        gt = gt[:gt.find('[s]')]
                        pred = pred[:pred.find('[s]')]

                    predicted_result_log += f'{gt:25s} | {pred:25s} | {confidence:0.4f}\t{str(pred == gt)}\n'
                predicted_result_log += f'{dashed_line}'
                print(predicted_result_log)
                log.write(predicted_result_log + '\n')

        # save model per 1e+5 iter.
        if (iteration + 1) % 1e+5 == 0:
            torch.save(
                model.state_dict(), f'./saved_models/{opt.exp_name}/iter_{iteration+1}.pth')

        if (iteration + 1) == opt.num_iter:
            print('end the training')
#             sys.exit()
            break
        iteration += 1

# %%
# parser = argparse.ArgumentParser()
# parser.add_argument('--exp_name', help='Where to store logs and models')
# parser.add_argument('--train_data', required=True, help='path to training dataset')
# parser.add_argument('--valid_data', required=True, help='path to validation dataset')
# parser.add_argument('--manualSeed', type=int, default=1111, help='for random seed setting')
# parser.add_argument('--workers', type=int, help='number of data loading workers', default=4)
# parser.add_argument('--batch_size', type=int, default=192, help='input batch size')
# parser.add_argument('--num_iter', type=int, default=300000, help='number of iterations to train for')
# parser.add_argument('--valInterval', type=int, default=2000, help='Interval between each validation')
# parser.add_argument('--saved_model', default='', help="path to model to continue training")
# parser.add_argument('--FT', action='store_true', help='whether to do fine-tuning')
# parser.add_argument('--adam', action='store_true', help='Whether to use adam (default is Adadelta)')
# parser.add_argument('--lr', type=float, default=1, help='learning rate, default=1.0 for Adadelta')
# parser.add_argument('--beta1', type=float, default=0.9, help='beta1 for adam. default=0.9')
# parser.add_argument('--rho', type=float, default=0.95, help='decay rate rho for Adadelta. default=0.95')
# parser.add_argument('--eps', type=float, default=1e-8, help='eps for Adadelta. default=1e-8')
# parser.add_argument('--grad_clip', type=float, default=5, help='gradient clipping value. default=5')
# parser.add_argument('--baiduCTC', action='store_true', help='for data_filtering_off mode')
# """ Data processing """
# parser.add_argument('--select_data', type=str, default='MJ-ST',
#                     help='select training data (default is MJ-ST, which means MJ and ST used as training data)')
# parser.add_argument('--batch_ratio', type=str, default='0.5-0.5',
#                     help='assign ratio for each selected data in the batch')
# parser.add_argument('--total_data_usage_ratio', type=str, default='1.0',
#                     help='total data usage ratio, this ratio is multiplied to total number of data.')
# parser.add_argument('--batch_max_length', type=int, default=25, help='maximum-label-length')
# parser.add_argument('--imgH', type=int, default=32, help='the height of the input image')
# parser.add_argument('--imgW', type=int, default=100, help='the width of the input image')
# parser.add_argument('--rgb', action='store_true', help='use rgb input')
# parser.add_argument('--character', type=str,
#                     default='0123456789abcdefghijklmnopqrstuvwxyz', help='character label')
# parser.add_argument('--sensitive', action='store_true', help='for sensitive character mode')
# parser.add_argument('--PAD', action='store_true', help='whether to keep ratio then pad for image resize')
# parser.add_argument('--data_filtering_off', action='store_true', help='for data_filtering_off mode')
# """ Model Architecture """
# parser.add_argument('--Transformation', type=str, required=True, help='Transformation stage. None|TPS')
# parser.add_argument('--FeatureExtraction', type=str, required=True,
#                     help='FeatureExtraction stage. VGG|RCNN|ResNet')
# parser.add_argument('--SequenceModeling', type=str, required=True, help='SequenceModeling stage. None|BiLSTM')
# parser.add_argument('--Prediction', type=str, required=True, help='Prediction stage. CTC|Attn')
# parser.add_argument('--num_fiducial', type=int, default=20, help='number of fiducial points of TPS-STN')
# parser.add_argument('--input_channel', type=int, default=1,
#                     help='the number of input channel of Feature extractor')
# parser.add_argument('--output_channel', type=int, default=512,
#                     help='the number of output channel of Feature extractor')
# parser.add_argument('--hidden_size', type=int, default=256, help='the size of the LSTM hidden state')

# %% [markdown]
# # 1. None-VGG-BiLSTM-CTC.pth (Best)

# %%
args = argparse.Namespace(
    train_data = "../datasets/forTrainingData/train",
    valid_data = "../datasets/forTrainingData/val",
    select_data = "01-02-03",
    batch_ratio = "0.3-0.3-0.4",
    Transformation = "None",
    FeatureExtraction = "VGG",
    SequenceModeling = "BiLSTM",
    Prediction = "CTC",
    saved_model = "models/None-VGG-BiLSTM-CTC.pth",
    FT = True,
    manualSeed = 213,
    
    # Add arg for Training
    num_gpu = None,
    exp_name = None,
    workers = 0,
    batch_size = 192,
    data_filtering_off = None,
    imgH = 32,
    imgW = 100,
    num_iter = 5000,
    valInterval = 100, 
    adam = None,
    lr = 1,
    beta1 = 0.9,
    rho = 0.95,
    eps = 1e-8,
    grad_clip = 5,
    baiduCTC = None,
    total_data_usage_ratio = "1.0",
    batch_max_length = 25,
    rgb = None,
    sensitive = None,
    PAD = None,
    num_fiducial = 20,
    input_channel = 1,
    output_channel = 512,
    hidden_size = 256,
    character = '0123456789abcdefghijklmnopqrstuvwxyz'
    
)

# %%
opt = args

if not opt.exp_name:
    opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
    opt.exp_name += f'-Seed{opt.manualSeed}'
    # print(opt.exp_name)

os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

""" vocab / character number configuration """
if opt.sensitive:
    # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

""" Seed and GPU setting """
# print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
torch.cuda.manual_seed(opt.manualSeed)

cudnn.benchmark = True
cudnn.deterministic = True
opt.num_gpu = torch.cuda.device_count()
# print('device count', opt.num_gpu)
if opt.num_gpu > 1:
    print('------ Use multi-GPU setting ------')
    print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
    # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
    opt.workers = opt.workers * opt.num_gpu
    opt.batch_size = opt.batch_size * opt.num_gpu

    """ previous version
    print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
    opt.batch_size = opt.batch_size * opt.num_gpu
    print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
    If you dont care about it, just commnet out these line.)
    opt.num_iter = int(opt.num_iter / opt.num_gpu)
    """

train(opt)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ../datasets/forTrainingData/train
# opt.select_data: ['01', '02', '03']
# opt.batch_ratio: ['0.3', '0.3', '0.4']
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 01
# sub-directory:	/01	 num samples: 2989
# num total samples of 01: 2989 x 1.0 (total_data_usage_ratio) = 2989
# num samples of 01 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 02
# sub-directory:	/02	 num samples: 2872
# num total samples of 02: 2872 x 1.0 (total_data_usage_ratio) = 2872
# num samples of 02 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 03
# sub-directory:	/03	 num samples: 119
# num total samples of 03: 119 x 1.0 (total_data_usage_ratio) = 119
# num samples of 03 per batch: 192 x 0.4 (batch_ratio) = 77
# --------------------------------------------------------------------------------
# Total_batch_size: 58+58+77 = 193
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/val	 dataset: /
# sub-directory:	/01	 num samples: 747
# sub-directory:	/02	 num samples: 718
# sub-directory:	/03	 num samples: 31
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 32 100 20 1 512 256 37 25 None VGG BiLSTM CTC
# loading pretrained model from models/None-VGG-BiLSTM-CTC.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=37, bias=True)
#   )
# )
# Trainable params num :  8451621
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# train_data: ../datasets/forTrainingData/train
# valid_data: ../datasets/forTrainingData/val
# select_data: ['01', '02', '03']
# batch_ratio: ['0.3', '0.3', '0.4']
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# saved_model: models/None-VGG-BiLSTM-CTC.pth
# FT: True
# manualSeed: 213
# num_gpu: 1
# exp_name: None-VGG-BiLSTM-CTC-Seed213
# workers: 0
# batch_size: 193
# data_filtering_off: None
# imgH: 32
# imgW: 100
# num_iter: 5000
# valInterval: 100
# adam: None
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: None
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# rgb: None
# sensitive: None
# PAD: None
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# num_class: 37
# ---------------------------------------
#
# [1/5000] Train loss: 4.73586, Valid loss: 3.47066, Elapsed_time: 4.47054
# Current_accuracy : 7.019, Current_norm_ED  : 0.32
# Best_accuracy    : 7.019, Best_norm_ED     : 0.32
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f12j25                | gmtes                     | 0.0007	False
# 994s16m10                 | owgilmad                  | 0.0002	False
# 2801                      | 2801                      | 0.5590	True
# 983e32f81                 | gededlpes                 | 0.0024	False
# 983e42726                 | weg                       | 0.0000	False
# --------------------------------------------------------------------------------
# [100/5000] Train loss: 0.35709, Valid loss: 0.24248, Elapsed_time: 26.04976
# Current_accuracy : 73.329, Current_norm_ED  : 0.95
# Best_accuracy    : 73.329, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b57g39                | 8094b359g39               | 0.1126	False
# 9012e32a19                | 9012e32a19                | 0.8285	True
# 983s15t75                 | 983s15t75                 | 0.7784	True
# 7103                      | 7103                      | 0.8793	True
# 4003                      | 4003                      | 0.7236	True
# --------------------------------------------------------------------------------
# [200/5000] Train loss: 0.08421, Valid loss: 0.19412, Elapsed_time: 41.87136
# Current_accuracy : 80.749, Current_norm_ED  : 0.96
# Best_accuracy    : 80.749, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8601                      | 8601                      | 0.7612	True
# 5801                      | 5801                      | 0.7341	True
# 8094h15b04                | 81094h15b04               | 0.0409	False
# 9901                      | 9901                      | 0.7459	True
# 8802                      | 8802                      | 0.4958	True
# --------------------------------------------------------------------------------
# [300/5000] Train loss: 0.04257, Valid loss: 0.18747, Elapsed_time: 57.68628
# Current_accuracy : 83.021, Current_norm_ED  : 0.97
# Best_accuracy    : 83.021, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6803                      | 6803                      | 0.7009	True
# 4702                      | 4302                      | 0.7934	False
# 983e21g11                 | 983e21g11                 | 0.8443	True
# 983b72a11                 | 983b72a11                 | 0.7327	True
# 994c35a18                 | 994ca18                   | 0.1614	False
# --------------------------------------------------------------------------------
# [400/5000] Train loss: 0.02390, Valid loss: 0.20420, Elapsed_time: 73.99482
# Current_accuracy : 84.425, Current_norm_ED  : 0.97
# Best_accuracy    : 84.425, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995b51j95                 | 995b51j95                 | 0.9574	True
# 9012f51r04                | 9012f51r04                | 0.9948	True
# 1001                      | 1001                      | 0.6322	True
# z                         | 995c1741                  | 0.1647	False
# 3902                      | 3902                      | 0.7762	True
# --------------------------------------------------------------------------------
# [500/5000] Train loss: 0.01346, Valid loss: 0.19340, Elapsed_time: 90.34606
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 85.762, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2901                      | 2901                      | 0.6565	True
# 3002                      | 3002                      | 0.6593	True
# 8093a21a25                | 8093a21a25                | 0.7781	True
# 9301                      | 9301                      | 0.7639	True
# 983s23g63                 | 983s23g63                 | 0.7070	True
# --------------------------------------------------------------------------------
# [600/5000] Train loss: 0.00799, Valid loss: 0.20285, Elapsed_time: 106.35893
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 85.896, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983b17k58                 | 983b17k58                 | 0.5299	True
# 983s11b50                 | 983s11b50                 | 0.3976	True
# c1051b1a04                | c1051b1a04                | 0.7681	True
# 7502                      | 7502                      | 0.8253	True
# 995m31b07                 | 995h31b07                 | 0.3875	False
# --------------------------------------------------------------------------------
# [700/5000] Train loss: 0.00459, Valid loss: 0.21315, Elapsed_time: 122.47507
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 85.896, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1801                      | 1801                      | 0.9901	True
# c1051m5a04                | c1005b5a04                | 0.1476	False
# 8093f12732                | 8093f12732                | 0.3853	True
# 8093f12732                | 8093f12732                | 0.6025	True
# 8094b21a05                | 8094d21a05                | 0.4851	False
# --------------------------------------------------------------------------------
# [800/5000] Train loss: 0.00272, Valid loss: 0.21744, Elapsed_time: 138.50840
# Current_accuracy : 85.628, Current_norm_ED  : 0.97
# Best_accuracy    : 85.896, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b64312                | 8108b64312                | 0.2254	True
# 8108b40n69                | 8108b40n69                | 0.8692	True
# 8094d11a11                | 8094d11a11                | 0.9601	True
# 5501                      | 5501                      | 0.9086	True
# 3603                      | 3603                      | 0.7652	True
# --------------------------------------------------------------------------------
# [900/5000] Train loss: 0.00173, Valid loss: 0.24248, Elapsed_time: 154.52787
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 85.896, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2502                      | 2502                      | 0.9357	True
# c1051b6a10                | c1051b6a10                | 0.6178	True
# 995c17a11                 | 995c17a11                 | 0.5313	True
# 8093d21a03                | 8093d21a03                | 0.9487	True
# 2402                      | 2402                      | 0.6724	True
# --------------------------------------------------------------------------------
# [1000/5000] Train loss: 0.00124, Valid loss: 0.23081, Elapsed_time: 170.52540
# Current_accuracy : 85.561, Current_norm_ED  : 0.97
# Best_accuracy    : 85.896, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012e31a76                | 9012e31a36                | 0.4863	False
# 8094d21a05                | 8094d2a05                 | 0.3428	False
# 8095a81v06                | 8095a81v06                | 0.8533	True
# 7702                      | 7702                      | 0.6507	True
# 983e11r11                 | 983f11r11                 | 0.9501	False
# --------------------------------------------------------------------------------
# [1100/5000] Train loss: 0.00098, Valid loss: 0.23301, Elapsed_time: 186.66095
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4303                      | 4303                      | 0.6521	True
# 8093a21a23                | 8093a21a23                | 0.3568	True
# 4001                      | 4001                      | 0.8872	True
# 9601                      | 9601                      | 0.9967	True
# 8109b42a11                | 8109b42a11                | 0.9890	True
# --------------------------------------------------------------------------------
# [1200/5000] Train loss: 0.00077, Valid loss: 0.23789, Elapsed_time: 202.86661
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2801                      | 2801                      | 0.3733	True
# 3401                      | 3401                      | 0.9987	True
# 8094h21f40                | 8094m21f40                | 0.3401	False
# 2801                      | 2801                      | 0.7057	True
# 2003                      | 2003                      | 0.5558	True
# --------------------------------------------------------------------------------
# [1300/5000] Train loss: 0.00059, Valid loss: 0.24644, Elapsed_time: 220.50829
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094d18f23                | 8094d18f23                | 0.8183	True
# 3703                      | 3703                      | 0.7725	True
# 995c44a10                 | 995c44a10                 | 0.6403	True
# 8602                      | 8602                      | 0.9026	True
# 995s13f07                 | 995s13f07                 | 0.4350	True
# --------------------------------------------------------------------------------
# [1400/5000] Train loss: 0.00049, Valid loss: 0.27154, Elapsed_time: 236.57812
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5601                      | 5601                      | 0.4725	True
# 3401                      | 3401                      | 0.9503	True
# 995h13b08                 | 995h13b08                 | 0.7146	True
# 4401                      | 4401                      | 0.9228	True
# 2703                      | 2703                      | 0.9381	True
# --------------------------------------------------------------------------------
# [1500/5000] Train loss: 0.00044, Valid loss: 0.25072, Elapsed_time: 252.73040
# Current_accuracy : 85.561, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f12j25                | 8093f12j25                | 0.4255	True
# 8093t42b13                | 8093t42b13                | 0.6303	True
# 8109b42a11                | 8109b42a11                | 0.5359	True
# 1803                      | 1803                      | 0.7327	True
# 983b72a11                 | 983b72a11                 | 0.9832	True
# --------------------------------------------------------------------------------
# [1600/5000] Train loss: 0.00037, Valid loss: 0.25317, Elapsed_time: 268.81594
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5302                      | 5302                      | 0.9015	True
# 8094s13b57                | 8094s13b57                | 0.6318	True
# 4702                      | 4702                      | 0.9930	True
# 0401                      | 0401                      | 0.8516	True
# 6801                      | 6801                      | 0.9718	True
# --------------------------------------------------------------------------------
# [1700/5000] Train loss: 0.00034, Valid loss: 0.25834, Elapsed_time: 284.97675
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 85.963, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e35321                 | 995e35321                 | 0.5475	True
# 1003                      | 1007                      | 0.4300	False
# 0705                      | 0705                      | 0.9948	True
# 983e42b50                 | 983e42b50                 | 0.5023	True
# 983s17t54                 | 983s17t54                 | 0.6465	True
# --------------------------------------------------------------------------------
# [1800/5000] Train loss: 0.00030, Valid loss: 0.26148, Elapsed_time: 301.46825
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8603                      | 8603                      | 0.6185	True
# 995h31b07                 | 995h31b07                 | 0.7527	True
# 3002                      | 3002                      | 0.9315	True
# 8094b61j58                | 8094b60j58                | 0.3896	False
# 2801                      | 2801                      | 0.7167	True
# --------------------------------------------------------------------------------
# [1900/5000] Train loss: 0.00028, Valid loss: 0.26389, Elapsed_time: 318.03184
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5001                      | 5001                      | 0.8190	True
# 983h13b14                 | 983h13b14                 | 0.9822	True
# 8094s13b57                | 8094s13b57                | 0.5755	True
# 8108f41b33                | 8108f41b33                | 0.7245	True
# 9604                      | 9604                      | 0.8853	True
# --------------------------------------------------------------------------------
# [2000/5000] Train loss: 0.00025, Valid loss: 0.26487, Elapsed_time: 334.39075
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b56r03                | 8094358r03                | 0.1492	False
# 983s11r11                 | 983s11r11                 | 0.9524	True
# 7002                      | 7002                      | 0.5091	True
# 983c33f23                 | 983c33f23                 | 0.9969	True
# 5602                      | 5602                      | 0.9848	True
# --------------------------------------------------------------------------------
# [2100/5000] Train loss: 0.00023, Valid loss: 0.26716, Elapsed_time: 350.96148
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.6082	True
# 9801                      | 9801                      | 0.7785	True
# 994e42b04                 | 994e42b04                 | 0.9600	True
# 1001                      | 1001                      | 0.9997	True
# 4801                      | 4801                      | 0.9696	True
# --------------------------------------------------------------------------------
# [2200/5000] Train loss: 0.00021, Valid loss: 0.26862, Elapsed_time: 367.21625
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5501                      | 5501                      | 0.8923	True
# 995e32b53                 | 99se32b53                 | 0.7016	False
# 995e36t39                 | 995e36t39                 | 0.6327	True
# 1003                      | 1003                      | 0.9959	True
# 6803                      | 6803                      | 0.9663	True
# --------------------------------------------------------------------------------
# [2300/5000] Train loss: 0.00019, Valid loss: 0.27200, Elapsed_time: 383.55343
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b61                   | 8108b61                   | 0.5353	True
# 8901                      | 8901                      | 0.8282	True
# 8094g14v04                | 8094914v04                | 0.4707	False
# 5602                      | 5602                      | 0.9881	True
# 9901                      | 9901                      | 0.4764	True
# --------------------------------------------------------------------------------
# [2400/5000] Train loss: 0.00018, Valid loss: 0.27665, Elapsed_time: 399.91334
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c50a20                 | 994c50a20                 | 0.7688	True
# 1311y21d33                | 1311y21d33                | 0.9700	True
# 995c44a10                 | 995c44a10                 | 0.5646	True
# 983h17b06                 | 883h17b06                 | 0.8222	False
# 9102                      | 9102                      | 0.9703	True
# --------------------------------------------------------------------------------
# [2500/5000] Train loss: 0.00017, Valid loss: 0.27443, Elapsed_time: 416.30549
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8403                      | 5403                      | 0.6925	False
# 5301                      | 5301                      | 0.8215	True
# 4801                      | 4801                      | 0.9543	True
# 8094e42a07                | 894e42a07                 | 0.4855	False
# 8109h23b19                | 8109h23b19                | 0.7539	True
# --------------------------------------------------------------------------------
# [2600/5000] Train loss: 0.00016, Valid loss: 0.27481, Elapsed_time: 432.70988
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109s20a15                | 8109s20a15                | 0.8863	True
# 8093f12a33                | 8093f12a33                | 0.2909	True
# 8108b61d35                | 8108b61d35                | 0.9448	True
# 8109b38a10                | 8109b38a10                | 0.2603	True
# 8093f12327                | 8093f12327                | 0.9265	True
# --------------------------------------------------------------------------------
# [2700/5000] Train loss: 0.00015, Valid loss: 0.27943, Elapsed_time: 449.03912
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109e42m70                | 8109e42m70                | 0.4452	True
# 995c44f29                 | 995e44f29                 | 0.1124	False
# 8109h13b19                | 8109m13b19                | 0.4951	False
# 9301                      | 9301                      | 0.9156	True
# 995h31b07                 | 995h31b07                 | 0.7900	True
# --------------------------------------------------------------------------------
# [2800/5000] Train loss: 0.00014, Valid loss: 0.28059, Elapsed_time: 465.40039
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5701                      | 5701                      | 0.9847	True
# 995b17r09                 | 995b17r09                 | 0.9917	True
# 8201                      | 8201                      | 0.9926	True
# 6803                      | 6803                      | 0.9481	True
# 983e41t31                 | 980e41731                 | 0.4753	False
# --------------------------------------------------------------------------------
# [2900/5000] Train loss: 0.00013, Valid loss: 0.27844, Elapsed_time: 481.77467
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108s16h50                | 8108s16h50                | 0.4718	True
# 9501                      | 9501                      | 0.5893	True
# 5101                      | 5101                      | 0.4437	True
# 983e32t92                 | 983e32792                 | 0.5546	False
# 0401                      | 0401                      | 0.9949	True
# --------------------------------------------------------------------------------
# [3000/5000] Train loss: 0.00013, Valid loss: 0.28484, Elapsed_time: 498.10664
# Current_accuracy : 85.762, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9301                      | 9301                      | 0.9806	True
# 2603                      | 2603                      | 0.9384	True
# 994c35a02                 | 994c35a02                 | 0.9375	True
# 982d43h40                 | 982d43h40                 | 0.9886	True
# 8802                      | 8802                      | 0.5323	True
# --------------------------------------------------------------------------------
# [3100/5000] Train loss: 0.00012, Valid loss: 0.28198, Elapsed_time: 514.33642
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093b12f23                | 805b2f3                   | 0.9447	False
# 994c35a02                 | 994c35a02                 | 0.9394	True
# 8094e28f43                | 8094e28f43                | 0.9799	True
# 1601                      | 1501                      | 0.9508	False
# 1603                      | 1603                      | 0.4474	True
# --------------------------------------------------------------------------------
# [3200/5000] Train loss: 0.00011, Valid loss: 0.31053, Elapsed_time: 533.14265
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b57g39                | 8094b59g39                | 0.9258	False
# 8603                      | 8603                      | 0.9268	True
# 0502                      | 0502                      | 0.9997	True
# p1139bgb37                | p139b9b37                 | 0.3622	False
# 7500                      | 7506                      | 0.7608	False
# --------------------------------------------------------------------------------
# [3300/5000] Train loss: 0.00011, Valid loss: 0.28723, Elapsed_time: 550.20516
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# c1051b8a03                | c1051b8a03                | 0.5344	True
# 2402                      | 2402                      | 0.9941	True
# 1402                      | 1402                      | 0.9985	True
# 4802                      | 4802                      | 0.8796	True
# 8093b16803                | 8093b16803                | 0.9002	True
# --------------------------------------------------------------------------------
# [3400/5000] Train loss: 0.00010, Valid loss: 0.28819, Elapsed_time: 566.47992
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094t43j23                | 8094t43j23                | 0.5572	True
# 7504                      | 7504                      | 0.9927	True
# 995e32b53                 | 995e32b53                 | 0.9812	True
# 5801                      | 5801                      | 0.6465	True
# 983s17t54                 | 983s17t54                 | 0.9976	True
# --------------------------------------------------------------------------------
# [3500/5000] Train loss: 0.00010, Valid loss: 0.28569, Elapsed_time: 582.68120
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4301                      | 4301                      | 0.9961	True
# 8109e51h38                | 8109e51h38                | 0.3908	True
# 995e36311                 | 995e36311                 | 0.9856	True
# 8093f12732                | 8093f12732                | 0.5649	True
# 8093a21a23                | 8093a21a23                | 0.2850	True
# --------------------------------------------------------------------------------
# [3600/5000] Train loss: 0.00010, Valid loss: 0.29050, Elapsed_time: 598.96951
# Current_accuracy : 86.096, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109e51h38                | 8109e51h38                | 0.3848	True
# 8109b42g26                | 8109b42g26                | 0.8385	True
# 8093s11a21                | 8093s11a21                | 0.8601	True
# 994c50a13                 | 994c50a13                 | 0.8505	True
# 8094h22f28                | 8094h22f28                | 0.9358	True
# --------------------------------------------------------------------------------
# [3700/5000] Train loss: 0.00009, Valid loss: 0.28772, Elapsed_time: 615.30370
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9503                      | 9503                      | 0.6171	True
# 7002                      | 7002                      | 0.8969	True
# 8802                      | 8802                      | 0.5667	True
# 1801                      | 1801                      | 0.9432	True
# 7002                      | 7002                      | 0.9689	True
# --------------------------------------------------------------------------------
# [3800/5000] Train loss: 0.00009, Valid loss: 0.31669, Elapsed_time: 631.54306
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c33a20                 | 994c33a20                 | 0.8731	True
# 8201                      | 8201                      | 0.6320	True
# 8109a31g66                | 8109a31g66                | 0.9443	True
# 983s11b50                 | 983s11b50                 | 0.9577	True
# 1803                      | 1803                      | 0.8883	True
# --------------------------------------------------------------------------------
# [3900/5000] Train loss: 0.00009, Valid loss: 0.28956, Elapsed_time: 647.76531
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8602                      | 8602                      | 0.9466	True
# 3802                      | 3802                      | 0.6068	True
# 2003                      | 2003                      | 0.5758	True
# 8601                      | 8601                      | 0.9549	True
# 4802                      | 4802                      | 0.9965	True
# --------------------------------------------------------------------------------
# [4000/5000] Train loss: 0.00008, Valid loss: 0.29256, Elapsed_time: 664.06322
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b56r03                | 8094b58r03                | 0.2025	False
# 8404                      | 8404                      | 0.9950	True
# 2703                      | 2703                      | 0.7326	True
# 995e33b46                 | 995e33b46                 | 0.8857	True
# 8093s11r05                | 8093s11r05                | 0.8708	True
# --------------------------------------------------------------------------------
# [4100/5000] Train loss: 0.00008, Valid loss: 0.29597, Elapsed_time: 680.36373
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983s11g21                 | 983s11g21                 | 0.9817	True
# 8501                      | 850                       | 0.3139	False
# 8109a21323                | 8109a21323                | 0.7526	True
# 983e42726                 | 983e42726                 | 0.9914	True
# 8109h13b19                | 8109m13b19                | 0.5682	False
# --------------------------------------------------------------------------------
# [4200/5000] Train loss: 0.00008, Valid loss: 0.29383, Elapsed_time: 696.64602
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6501                      | 6501                      | 0.9104	True
# 5501                      | 5501                      | 0.9847	True
# 983c33f23                 | 983c33f23                 | 0.9992	True
# 6501                      | 6501                      | 0.9969	True
# 9012f51r04                | 9012f51r04                | 0.9960	True
# --------------------------------------------------------------------------------
# [4300/5000] Train loss: 0.00008, Valid loss: 0.29640, Elapsed_time: 713.00490
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3002                      | 3002                      | 0.9908	True
# 9012f21a19                | 9012f21a19                | 0.9385	True
# 9503                      | 9503                      | 1.0000	True
# 8108f41b33                | 8108f41b33                | 0.8400	True
# 6501                      | 6501                      | 0.7815	True
# --------------------------------------------------------------------------------
# [4400/5000] Train loss: 0.00008, Valid loss: 0.29359, Elapsed_time: 729.38389
# Current_accuracy : 85.896, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012n15b17                | 9012h15b17                | 0.3826	False
# 2703                      | 2703                      | 0.6626	True
# 5903                      | 5903                      | 0.9340	True
# 0902                      | 0902                      | 0.9691	True
# 8109b38a10                | 8109b38a10                | 0.5268	True
# --------------------------------------------------------------------------------
# [4500/5000] Train loss: 0.00007, Valid loss: 0.29191, Elapsed_time: 745.68314
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b61j58                | 8094b60j58                | 0.4585	False
# 8109h23b19                | 8109h23b19                | 0.6361	True
# 9901                      | 9901                      | 0.8274	True
# 7202                      | 7202                      | 0.9589	True
# 8093f12a33                | 8093f12a33                | 0.7329	True
# --------------------------------------------------------------------------------
# [4600/5000] Train loss: 0.00007, Valid loss: 0.29391, Elapsed_time: 761.90579
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5501                      | 5501                      | 0.9094	True
# 3702                      | 3702                      | 0.8980	True
# 9012f51r04                | 9012f51r04                | 0.9971	True
# 983s17t54                 | 983s17t54                 | 0.9965	True
# 7203                      | 7203                      | 0.9997	True
# --------------------------------------------------------------------------------
# [4700/5000] Train loss: 0.00007, Valid loss: 0.32663, Elapsed_time: 778.13634
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4003                      | 4003                      | 0.9999	True
# 4901                      | 4901                      | 0.5248	True
# 8094e12a23                | 8094e12a23                | 0.9584	True
# 995c43f30                 | 995c43f30                 | 0.8600	True
# 8093a21a25                | 8093a21a25                | 0.7386	True
# --------------------------------------------------------------------------------
# [4800/5000] Train loss: 0.00007, Valid loss: 0.29366, Elapsed_time: 794.42823
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9601                      | 9601                      | 0.9776	True
# 4301                      | 4301                      | 0.9972	True
# 8109s24g03                | 8109s24g03                | 0.9998	True
# 4003                      | 4003                      | 0.8442	True
# 5701                      | 5501                      | 0.5706	False
# --------------------------------------------------------------------------------
# [4900/5000] Train loss: 0.00006, Valid loss: 0.29501, Elapsed_time: 810.69239
# Current_accuracy : 85.829, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36t39                 | 995e36t39                 | 0.6376	True
# 8094d11a11                | 8094d11a11                | 0.8950	True
# 8601                      | 8601                      | 0.9938	True
# 5903                      | 5903                      | 0.5736	True
# 3004                      | 3004                      | 0.7564	True
# --------------------------------------------------------------------------------
# [5000/5000] Train loss: 0.00006, Valid loss: 0.29756, Elapsed_time: 826.92030
# Current_accuracy : 85.963, Current_norm_ED  : 0.97
# Best_accuracy    : 86.096, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8801                      | 8801                      | 0.6157	True
# 8094d21a05                | 8094d2a05                 | 0.4054	False
# 8801                      | 8801                      | 0.4841	True
# 3902                      | 8902                      | 0.9962	False
# 4802                      | 4802                      | 0.9985	True
# --------------------------------------------------------------------------------
# end the training

# %% [markdown]
# # 2. None-VGG-None-CTC.pth

# %%
args = argparse.Namespace(
    train_data = "../datasets/forTrainingData/train",
    valid_data = "../datasets/forTrainingData/val",
    select_data = "01-02-03",
    batch_ratio = "0.3-0.3-0.4",
    Transformation = "None",
    FeatureExtraction = "VGG",
    SequenceModeling = "None",
    Prediction = "CTC",
    saved_model = "models/None-VGG-None-CTC.pth",
    FT = True,
    manualSeed = 213,
    
    # Add arg for Training
    num_gpu = None,
    exp_name = None,
    workers = 0,
    batch_size = 192,
    data_filtering_off = None,
    imgH = 32,
    imgW = 100,
    num_iter = 5000,
    valInterval = 100, 
    adam = None,
    lr = 1,
    beta1 = 0.9,
    rho = 0.95,
    eps = 1e-8,
    grad_clip = 5,
    baiduCTC = None,
    total_data_usage_ratio = "1.0",
    batch_max_length = 25,
    rgb = None,
    sensitive = None,
    PAD = None,
    num_fiducial = 20,
    input_channel = 1,
    output_channel = 512,
    hidden_size = 256,
    character = '0123456789abcdefghijklmnopqrstuvwxyz'
    
)

# %%
opt = args

if not opt.exp_name:
    opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
    opt.exp_name += f'-Seed{opt.manualSeed}'
    # print(opt.exp_name)

os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

""" vocab / character number configuration """
if opt.sensitive:
    # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

""" Seed and GPU setting """
# print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
torch.cuda.manual_seed(opt.manualSeed)

cudnn.benchmark = True
cudnn.deterministic = True
opt.num_gpu = torch.cuda.device_count()
# print('device count', opt.num_gpu)
if opt.num_gpu > 1:
    print('------ Use multi-GPU setting ------')
    print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
    # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
    opt.workers = opt.workers * opt.num_gpu
    opt.batch_size = opt.batch_size * opt.num_gpu

    """ previous version
    print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
    opt.batch_size = opt.batch_size * opt.num_gpu
    print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
    If you dont care about it, just commnet out these line.)
    opt.num_iter = int(opt.num_iter / opt.num_gpu)
    """

train(opt)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ../datasets/forTrainingData/train
# opt.select_data: ['01', '02', '03']
# opt.batch_ratio: ['0.3', '0.3', '0.4']
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 01
# sub-directory:	/01	 num samples: 2989
# num total samples of 01: 2989 x 1.0 (total_data_usage_ratio) = 2989
# num samples of 01 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 02
# sub-directory:	/02	 num samples: 2872
# num total samples of 02: 2872 x 1.0 (total_data_usage_ratio) = 2872
# num samples of 02 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 03
# sub-directory:	/03	 num samples: 119
# num total samples of 03: 119 x 1.0 (total_data_usage_ratio) = 119
# num samples of 03 per batch: 192 x 0.4 (batch_ratio) = 77
# --------------------------------------------------------------------------------
# Total_batch_size: 58+58+77 = 193
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/val	 dataset: /
# sub-directory:	/01	 num samples: 747
# sub-directory:	/02	 num samples: 718
# sub-directory:	/03	 num samples: 31
# --------------------------------------------------------------------------------
# No Transformation module specified
# No SequenceModeling module specified
# model input parameters 32 100 20 1 512 256 37 25 None VGG None CTC
# loading pretrained model from models/None-VGG-None-CTC.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (Prediction): Linear(in_features=512, out_features=37, bias=True)
#   )
# )
# Trainable params num :  5568805
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# train_data: ../datasets/forTrainingData/train
# valid_data: ../datasets/forTrainingData/val
# select_data: ['01', '02', '03']
# batch_ratio: ['0.3', '0.3', '0.4']
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: None
# Prediction: CTC
# saved_model: models/None-VGG-None-CTC.pth
# FT: True
# manualSeed: 213
# num_gpu: 1
# exp_name: None-VGG-None-CTC-Seed213
# workers: 0
# batch_size: 193
# data_filtering_off: None
# imgH: 32
# imgW: 100
# num_iter: 5000
# valInterval: 100
# adam: None
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: None
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# rgb: None
# sensitive: None
# PAD: None
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# num_class: 37
# ---------------------------------------
#
# [1/5000] Train loss: 15.51218, Valid loss: 5.46578, Elapsed_time: 0.13375
# Current_accuracy : 0.134, Current_norm_ED  : 0.17
# Best_accuracy    : 0.134, Best_norm_ED     : 0.17
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0601                      | oal                       | 0.0698	False
# 3401                      | 9a                        | 0.0328	False
# 1003                      | po                        | 0.0094	False
# 8108b61619                | gesrbigis                 | 0.0063	False
# 9012f11a20                | dizifiazs                 | 0.0025	False
# --------------------------------------------------------------------------------
# [100/5000] Train loss: 0.52081, Valid loss: 0.27010, Elapsed_time: 14.24310
# Current_accuracy : 71.123, Current_norm_ED  : 0.94
# Best_accuracy    : 71.123, Best_norm_ED     : 0.94
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6503                      | 6503                      | 0.1889	True
# 1301                      | 1301                      | 0.4886	True
# 8093f12732                | 8093f12732                | 0.6808	True
# 9901                      | 9901                      | 0.6141	True
# 4904                      | 4904                      | 0.7828	True
# --------------------------------------------------------------------------------
# [200/5000] Train loss: 0.11621, Valid loss: 0.21513, Elapsed_time: 28.47717
# Current_accuracy : 78.142, Current_norm_ED  : 0.96
# Best_accuracy    : 78.142, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6803                      | 6803                      | 0.8520	True
# 983s17t54                 | 983s17t54                 | 0.4400	True
# 3401                      | 3401                      | 0.8929	True
# 4702                      | 4702                      | 0.8945	True
# 983s15t75                 | 983s15t75                 | 0.4696	True
# --------------------------------------------------------------------------------
# [300/5000] Train loss: 0.06488, Valid loss: 0.21448, Elapsed_time: 42.69601
# Current_accuracy : 80.013, Current_norm_ED  : 0.96
# Best_accuracy    : 80.013, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094d15a01                | 9094d14a01                | 0.0120	False
# 8109h14f16                | 8109h14f16                | 0.3143	True
# 983b75a11                 | 983b75a11                 | 0.8126	True
# 3401                      | 3401                      | 0.9927	True
# 0601                      | 0601                      | 0.9772	True
# --------------------------------------------------------------------------------
# [400/5000] Train loss: 0.03937, Valid loss: 0.22285, Elapsed_time: 56.91695
# Current_accuracy : 80.749, Current_norm_ED  : 0.96
# Best_accuracy    : 80.749, Best_norm_ED     : 0.96
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109b51r56                | 8109b1r56                 | 0.2895	False
# 8702                      | 8302                      | 0.5701	False
# 5101                      | 5601                      | 0.7817	False
# 995e36t39                 | 995e36t39                 | 0.9550	True
# 9012f41a18                | 9012f41a18                | 0.2383	True
# --------------------------------------------------------------------------------
# [500/5000] Train loss: 0.02552, Valid loss: 0.21908, Elapsed_time: 71.12743
# Current_accuracy : 82.086, Current_norm_ED  : 0.97
# Best_accuracy    : 82.086, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995b11t51                 | 995b11f51                 | 0.1975	False
# 2502                      | 2502                      | 0.9875	True
# 8093s11r05                | 8093s11r05                | 0.8339	True
# 983d31f26                 | 983d1f26                  | 0.2858	False
# 8702                      | 8302                      | 0.7168	False
# --------------------------------------------------------------------------------
# [600/5000] Train loss: 0.01785, Valid loss: 0.22713, Elapsed_time: 85.38927
# Current_accuracy : 82.553, Current_norm_ED  : 0.97
# Best_accuracy    : 82.553, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093b12f24                | 8093b12f24                | 0.5771	True
# 8095a81v06                | 8095a81v06                | 0.3542	True
# 9703                      | 9703                      | 0.4041	True
# 1601                      | 1501                      | 0.9964	False
# 6802                      | 6802                      | 0.9933	True
# --------------------------------------------------------------------------------
# [700/5000] Train loss: 0.01175, Valid loss: 0.23649, Elapsed_time: 99.61196
# Current_accuracy : 82.553, Current_norm_ED  : 0.97
# Best_accuracy    : 82.553, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1003                      | 1003                      | 0.9730	True
# 4001                      | 4001                      | 0.9923	True
# 995c44a09                 | 995c44a09                 | 0.5346	True
# 8802                      | 8802                      | 0.8440	True
# 4003                      | 4003                      | 0.7587	True
# --------------------------------------------------------------------------------
# [800/5000] Train loss: 0.00852, Valid loss: 0.25664, Elapsed_time: 113.76197
# Current_accuracy : 82.553, Current_norm_ED  : 0.97
# Best_accuracy    : 82.553, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5903                      | 5903                      | 1.0000	True
# 9012e31b68                | 9012e31b68                | 0.3235	True
# 4003                      | 4003                      | 0.9996	True
# 8109b22d83                | 8109b22d13                | 0.2626	False
# 6903                      | 6903                      | 0.9990	True
# --------------------------------------------------------------------------------
# [900/5000] Train loss: 0.00657, Valid loss: 0.23328, Elapsed_time: 127.95239
# Current_accuracy : 83.155, Current_norm_ED  : 0.97
# Best_accuracy    : 83.155, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2903                      | 2803                      | 0.6638	False
# 983c33f22                 | 983c33f22                 | 0.5228	True
# 8093f41a05                | 8093f41a04                | 0.2330	False
# 8109b51r56                | 8109b51r56                | 0.4959	True
# 6103                      | 6103                      | 0.9702	True
# --------------------------------------------------------------------------------
# [1000/5000] Train loss: 0.00494, Valid loss: 0.24111, Elapsed_time: 142.23999
# Current_accuracy : 83.356, Current_norm_ED  : 0.97
# Best_accuracy    : 83.356, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.9706	True
# 9012e32a19                | 9012e32a19                | 0.5679	True
# 995e33b46                 | 995e33b46                 | 0.9424	True
# 994f52b21                 | 994f52b21                 | 0.5006	True
# 4001                      | 4001                      | 0.9992	True
# --------------------------------------------------------------------------------
# [1100/5000] Train loss: 0.00361, Valid loss: 0.26487, Elapsed_time: 156.44335
# Current_accuracy : 83.757, Current_norm_ED  : 0.97
# Best_accuracy    : 83.757, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0103                      | 0103                      | 0.9298	True
# 994f92a05                 | 994f92a05                 | 0.7982	True
# 8108f31322                | 8108f31322                | 0.9649	True
# 0705                      | 0705                      | 0.9161	True
# 8094s13b57                | 8094s13b57                | 0.8998	True
# --------------------------------------------------------------------------------
# [1200/5000] Train loss: 0.00269, Valid loss: 0.26373, Elapsed_time: 171.44155
# Current_accuracy : 83.289, Current_norm_ED  : 0.97
# Best_accuracy    : 83.757, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4001                      | 14801                     | 0.5834	False
# 983e33t54                 | 983e33t54                 | 0.4490	True
# 983e42726                 | 983e42726                 | 0.5219	True
# 0401                      | 0401                      | 0.9899	True
# 3703                      | 3703                      | 1.0000	True
# --------------------------------------------------------------------------------
# [1300/5000] Train loss: 0.00208, Valid loss: 0.26561, Elapsed_time: 185.59740
# Current_accuracy : 83.623, Current_norm_ED  : 0.97
# Best_accuracy    : 83.757, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.9696	True
# 995e36t39                 | 995e36t39                 | 0.8775	True
# 9604                      | 7604                      | 0.9418	False
# 995b51j95                 | 995b51j95                 | 0.9882	True
# 8094s20b51                | 8094s20b51                | 0.7316	True
# --------------------------------------------------------------------------------
# [1400/5000] Train loss: 0.00142, Valid loss: 0.27665, Elapsed_time: 199.87512
# Current_accuracy : 83.690, Current_norm_ED  : 0.97
# Best_accuracy    : 83.757, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8201                      | 8201                      | 0.9985	True
# 983s11b41                 | 983s11b41                 | 0.7371	True
# 983b75a07                 | 983b75a07                 | 0.9657	True
# 8109h15b23                | 8109h15b23                | 0.3155	True
# 983s17k49                 | 983s17k49                 | 0.5231	True
# --------------------------------------------------------------------------------
# [1500/5000] Train loss: 0.00156, Valid loss: 0.27209, Elapsed_time: 214.03362
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.024, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2604                      | 2604                      | 0.7389	True
# 8108b61307                | 8108b61307                | 0.1178	True
# 4001                      | 4001                      | 0.9929	True
# 994c32a14                 | 994c32a14                 | 0.4100	True
# 983e33t54                 | 983e33t54                 | 0.5438	True
# --------------------------------------------------------------------------------
# [1600/5000] Train loss: 0.00178, Valid loss: 0.28054, Elapsed_time: 228.24927
# Current_accuracy : 84.225, Current_norm_ED  : 0.97
# Best_accuracy    : 84.225, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2802                      | 2802                      | 1.0000	True
# 7002                      | 7002                      | 0.8833	True
# 8094h15b11                | 8094h15b11                | 0.8285	True
# 5602                      | 5602                      | 0.9842	True
# 8093t42b13                | 8093t47b13                | 0.6685	False
# --------------------------------------------------------------------------------
# [1700/5000] Train loss: 0.00087, Valid loss: 0.28911, Elapsed_time: 242.40173
# Current_accuracy : 83.757, Current_norm_ED  : 0.97
# Best_accuracy    : 84.225, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093a21307                | 8093a21307                | 0.9938	True
# 8093e25b07                | 8093e25b07                | 0.6851	True
# 5603                      | 5603                      | 0.9997	True
# 1301                      | 1301                      | 0.9412	True
# 5301                      | 5301                      | 0.9975	True
# --------------------------------------------------------------------------------
# [1800/5000] Train loss: 0.00079, Valid loss: 0.28499, Elapsed_time: 256.61015
# Current_accuracy : 83.957, Current_norm_ED  : 0.97
# Best_accuracy    : 84.225, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983c33f23                 | 983c33f23                 | 0.7270	True
# 8094s20b51                | 8094s20b51                | 0.7093	True
# 6101                      | 6101                      | 1.0000	True
# 2703                      | 2703                      | 0.9992	True
# 995h13b08                 | 995h13b08                 | 0.9567	True
# --------------------------------------------------------------------------------
# [1900/5000] Train loss: 0.00154, Valid loss: 0.27737, Elapsed_time: 270.72960
# Current_accuracy : 84.693, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983f11a51                 | 983f11a51                 | 0.8794	True
# 4402                      | 44102                     | 0.8347	False
# 4301                      | 4301                      | 0.5573	True
# 7702                      | 7702                      | 0.7702	True
# 1311y21d34                | 1311y21d34                | 0.5582	True
# --------------------------------------------------------------------------------
# [2000/5000] Train loss: 0.00058, Valid loss: 0.30631, Elapsed_time: 284.95282
# Current_accuracy : 83.957, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e21f64                 | 995e21f64                 | 0.9310	True
# 8093s11r0s                | 8093s11r05                | 0.9596	False
# 8093b16803                | 8093b16803                | 0.9970	True
# 8109s18f34                | 8109s18f34                | 0.7928	True
# 8603                      | 8603                      | 1.0000	True
# --------------------------------------------------------------------------------
# [2100/5000] Train loss: 0.00045, Valid loss: 0.31266, Elapsed_time: 299.09867
# Current_accuracy : 83.356, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4702                      | 4702                      | 0.9929	True
# 8109b22d83                | 8109b22d18                | 0.1586	False
# 994c33a20                 | 994c33a20                 | 0.9876	True
# 5302                      | 5302                      | 0.8528	True
# 8093f12a33                | 8093f12a33                | 0.8474	True
# --------------------------------------------------------------------------------
# [2200/5000] Train loss: 0.00044, Valid loss: 0.30742, Elapsed_time: 313.50799
# Current_accuracy : 83.890, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0705                      | 0705                      | 0.9995	True
# 995b17r09                 | 995b17r09                 | 0.7947	True
# 994c32a14                 | 994c32a14                 | 0.7529	True
# 8094d15a01                | 8094d15a01                | 0.4982	True
# 8094h13b01                | 8094h13b01                | 0.2653	True
# --------------------------------------------------------------------------------
# [2300/5000] Train loss: 0.00050, Valid loss: 0.32584, Elapsed_time: 327.81588
# Current_accuracy : 84.225, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094h15b11                | 8094h15b11                | 0.8575	True
# 9503                      | 9503                      | 1.0000	True
# 995e21f64                 | 995e21f64                 | 0.9143	True
# 6503                      | 6503                      | 0.8085	True
# 9012f41a09                | 9012f41a09                | 0.4465	True
# --------------------------------------------------------------------------------
# [2400/5000] Train loss: 0.00041, Valid loss: 0.31340, Elapsed_time: 341.98671
# Current_accuracy : 84.425, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4001                      | 4001                      | 0.9767	True
# 3603                      | 3603                      | 0.8575	True
# 4001                      | 4001                      | 0.8209	True
# 994c33a20                 | 994c33a20                 | 0.5324	True
# 7002                      | 7002                      | 0.6012	True
# --------------------------------------------------------------------------------
# [2500/5000] Train loss: 0.00033, Valid loss: 0.31702, Elapsed_time: 356.25672
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# b109s23f42                | 8109s23f42                | 0.9490	False
# 8109h13b19                | 8109mh13b19               | 0.5143	False
# 7002                      | 7002                      | 0.9621	True
# 3101                      | 3101                      | 0.9170	True
# 8094h13b01                | 8094h13b01                | 0.3757	True
# --------------------------------------------------------------------------------
# [2600/5000] Train loss: 0.00035, Valid loss: 0.31933, Elapsed_time: 371.13118
# Current_accuracy : 84.225, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.6095	True
# 1601                      | 1501                      | 0.9998	False
# 5101                      | 5101                      | 0.9582	True
# 7902                      | 7902                      | 0.7081	True
# 8201                      | 8201                      | 0.8487	True
# --------------------------------------------------------------------------------
# [2700/5000] Train loss: 0.00041, Valid loss: 0.29101, Elapsed_time: 385.65124
# Current_accuracy : 84.291, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f12a33                | 8093f12a33                | 0.4837	True
# 6604                      | 6604                      | 0.9558	True
# c1051b8a03                | c1051b8a03                | 0.5295	True
# 995e32b53                 | 995e32b53                 | 0.8899	True
# 1604                      | 1604                      | 0.4436	True
# --------------------------------------------------------------------------------
# [2800/5000] Train loss: 0.00029, Valid loss: 0.31954, Elapsed_time: 400.00402
# Current_accuracy : 84.225, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4001                      | 4001                      | 0.7974	True
# 4802                      | 4802                      | 0.9827	True
# 2801                      | 2801                      | 1.0000	True
# 8109b26a94                | 8109b36a94                | 0.9999	False
# 8093f41a05                | 8093f41a04                | 0.6758	False
# --------------------------------------------------------------------------------
# [2900/5000] Train loss: 0.00022, Valid loss: 0.31846, Elapsed_time: 414.13619
# Current_accuracy : 84.158, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4901                      | 4901                      | 0.6228	True
# 7503                      | 7503                      | 0.9996	True
# 994e42b04                 | 994e42b04                 | 0.9635	True
# 6002                      | 6002                      | 0.9633	True
# 8094t43j23                | 8094t43j23                | 0.9898	True
# --------------------------------------------------------------------------------
# [3000/5000] Train loss: 0.00039, Valid loss: 0.33166, Elapsed_time: 428.29241
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995c44f29                 | 995c44f29                 | 0.9960	True
# 8094e12r07                | 8094e12r07                | 0.4784	True
# 9012e31b68                | 9012e31b68                | 0.6391	True
# 7002                      | 7002                      | 0.9722	True
# 8093f41a05                | 8093f41a04                | 0.5974	False
# --------------------------------------------------------------------------------
# [3100/5000] Train loss: 0.00034, Valid loss: 0.29746, Elapsed_time: 442.66706
# Current_accuracy : 84.492, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983s11r12                 | 983s11r12                 | 0.4767	True
# 8403                      | 5403                      | 0.2869	False
# 995c44a09                 | 995c44a09                 | 0.4135	True
# 6903                      | 6903                      | 0.9998	True
# 994e42b04                 | 994e42b04                 | 0.7477	True
# --------------------------------------------------------------------------------
# [3200/5000] Train loss: 0.00021, Valid loss: 0.32383, Elapsed_time: 457.68527
# Current_accuracy : 84.091, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e24r04                 | 995e24r04                 | 0.9594	True
# 3504                      | 3504                      | 0.9949	True
# 7702                      | 7702                      | 0.9738	True
# 995e35318                 | 995e35318                 | 0.9642	True
# 2801                      | 2801                      | 1.0000	True
# --------------------------------------------------------------------------------
# [3300/5000] Train loss: 0.00017, Valid loss: 0.33019, Elapsed_time: 472.19567
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f12a33                | 8093f12a33                | 0.5599	True
# 983e42726                 | 983e42726                 | 0.5125	True
# 2702                      | 2702                      | 0.6336	True
# 7002                      | 7002                      | 0.5067	True
# 8093d21a03                | 8093d21a03                | 0.7363	True
# --------------------------------------------------------------------------------
# [3400/5000] Train loss: 0.00016, Valid loss: 0.33563, Elapsed_time: 486.48181
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094h13b08                | 8094h13b08                | 0.7068	True
# 8094e28f42                | 8094e28f42                | 0.4094	True
# 8093d41a15                | 803d41a15                 | 0.4039	False
# 8109b42g26                | 8109b42g26                | 0.9981	True
# 983e41f22                 | 903e41f22                 | 0.1983	False
# --------------------------------------------------------------------------------
# [3500/5000] Train loss: 0.00051, Valid loss: 0.30610, Elapsed_time: 500.78313
# Current_accuracy : 84.358, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9901                      | 9901                      | 1.0000	True
# 8094t15j69                | 8094tf15j69               | 0.6467	False
# 8094b21a05                | 8094d21a05                | 0.9124	False
# 8109e42m70                | 8109e42m70                | 0.9945	True
# 8093f12327                | 8093f12327                | 0.7030	True
# --------------------------------------------------------------------------------
# [3600/5000] Train loss: 0.00026, Valid loss: 0.31750, Elapsed_time: 514.98048
# Current_accuracy : 84.626, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0705                      | 0705                      | 0.5737	True
# 3701                      | 3701                      | 0.9986	True
# 8108b38m51                | 8108b38m51                | 0.8681	True
# 0502                      | 05802                     | 0.3874	False
# 1701                      | 1701                      | 0.6679	True
# --------------------------------------------------------------------------------
# [3700/5000] Train loss: 0.00016, Valid loss: 0.33408, Elapsed_time: 529.13172
# Current_accuracy : 84.158, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0705                      | 0705                      | 1.0000	True
# 9012e32a19                | 9012e32a19                | 0.9460	True
# 8094h13b12                | 8094h13b12                | 0.3010	True
# 983d11f24                 | 983d11f24                 | 0.9875	True
# 8201                      | 8201                      | 0.9992	True
# --------------------------------------------------------------------------------
# [3800/5000] Train loss: 0.00013, Valid loss: 0.34729, Elapsed_time: 544.12848
# Current_accuracy : 84.024, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4702                      | 4902                      | 0.9600	False
# 4901                      | 4901                      | 0.9996	True
# 8094e12r07                | 8094e12r07                | 0.6719	True
# 9012f51r04                | 9012f51r04                | 0.9942	True
# 7203                      | 7203                      | 0.9982	True
# --------------------------------------------------------------------------------
# [3900/5000] Train loss: 0.00013, Valid loss: 0.34704, Elapsed_time: 558.62585
# Current_accuracy : 84.091, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5603                      | 5603                      | 1.0000	True
# 6903                      | 6703                      | 0.9904	False
# 4501                      | 4501                      | 0.9954	True
# 8094e28f43                | 8094e28f43                | 0.9991	True
# 983b75a07                 | 983b75a07                 | 0.9919	True
# --------------------------------------------------------------------------------
# [4000/5000] Train loss: 0.00012, Valid loss: 0.34403, Elapsed_time: 573.37041
# Current_accuracy : 84.425, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094t13f32                | 8094t13f32                | 0.8142	True
# 5002                      | 5002                      | 0.9996	True
# 9012f21a19                | 9012f21a19                | 0.9964	True
# 983b15a08                 | 983b15a08                 | 0.9978	True
# 8601                      | 8501                      | 0.4434	False
# --------------------------------------------------------------------------------
# [4100/5000] Train loss: 0.00038, Valid loss: 0.32268, Elapsed_time: 587.85658
# Current_accuracy : 84.425, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1003                      | 1003                      | 0.9998	True
# 8094bs8f48                | 8094b5f48                 | 0.4035	False
# 3701                      | 3701                      | 0.9968	True
# 4301                      | 4301                      | 0.8371	True
# 4603                      | 4603                      | 0.9716	True
# --------------------------------------------------------------------------------
# [4200/5000] Train loss: 0.00013, Valid loss: 0.34691, Elapsed_time: 602.27428
# Current_accuracy : 84.158, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7901                      | 43904                     | 0.8712	False
# 8603                      | 8603                      | 0.6300	True
# 7702                      | 7702                      | 0.9471	True
# 983e42b50                 | 983e42b50                 | 0.5735	True
# 983e41t31                 | 983e41t31                 | 0.3827	True
# --------------------------------------------------------------------------------
# [4300/5000] Train loss: 0.00012, Valid loss: 0.34639, Elapsed_time: 616.68564
# Current_accuracy : 84.291, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c32a14                 | 994c32a14                 | 0.8151	True
# 8802                      | 8802                      | 0.9999	True
# 7502                      | 7502                      | 0.9694	True
# 995b17a18                 | 995b17a18                 | 0.6681	True
# 6802                      | 6802                      | 0.5993	True
# --------------------------------------------------------------------------------
# [4400/5000] Train loss: 0.00010, Valid loss: 0.34962, Elapsed_time: 631.00913
# Current_accuracy : 84.225, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36t39                 | 995e36t39                 | 0.8124	True
# 1003                      | 1003                      | 0.9986	True
# 3002                      | 3002                      | 0.9981	True
# 8603                      | 8603                      | 1.0000	True
# 5902                      | 502                       | 0.6806	False
# --------------------------------------------------------------------------------
# [4500/5000] Train loss: 0.00011, Valid loss: 0.34829, Elapsed_time: 645.16328
# Current_accuracy : 84.492, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5002                      | 5002                      | 0.9984	True
# 983s17t54                 | 983s17t54                 | 0.3360	True
# 8109t21b16                | 8109t21b16                | 0.9997	True
# 7503                      | 7503                      | 0.5417	True
# 8603                      | 8603                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4600/5000] Train loss: 0.00012, Valid loss: 0.34752, Elapsed_time: 659.32121
# Current_accuracy : 84.559, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109b42g26                | 8109b42g26                | 0.9920	True
# 983s11r16                 | 983s11r16                 | 0.8433	True
# 8603                      | 8603                      | 1.0000	True
# 983s11b49                 | 983s11b49                 | 0.5092	True
# 4501                      | 4501                      | 0.8860	True
# --------------------------------------------------------------------------------
# [4700/5000] Train loss: 0.00010, Valid loss: 0.34250, Elapsed_time: 673.55521
# Current_accuracy : 84.559, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b57g39                | 8094b59g39                | 0.6687	False
# 995s13f07                 | 995s13f07                 | 0.4970	True
# 8801                      | 8801                      | 0.9999	True
# 3601                      | 3601                      | 0.9504	True
# 994f92a09                 | 994f92a09                 | 0.9182	True
# --------------------------------------------------------------------------------
# [4800/5000] Train loss: 0.00014, Valid loss: 0.34539, Elapsed_time: 687.81174
# Current_accuracy : 84.492, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6501                      | 6501                      | 0.8916	True
# 8094e28f43                | 8094e28f43                | 0.9966	True
# 995e36311                 | 995e36311                 | 1.0000	True
# 5902                      | 5902                      | 0.5153	True
# 9301                      | 9901                      | 0.7785	False
# --------------------------------------------------------------------------------
# [4900/5000] Train loss: 0.00014, Valid loss: 0.35609, Elapsed_time: 702.15663
# Current_accuracy : 84.358, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7204                      | 7204                      | 1.0000	True
# 994c50a03                 | 994c50a03                 | 0.6367	True
# 983s17t54                 | 983s17t54                 | 0.9956	True
# 8094h13b08                | 8094h13b08                | 0.7206	True
# 983h17b06                 | 983h17b06                 | 0.3414	True
# --------------------------------------------------------------------------------
# [5000/5000] Train loss: 0.00012, Valid loss: 0.35267, Elapsed_time: 716.54431
# Current_accuracy : 84.559, Current_norm_ED  : 0.97
# Best_accuracy    : 84.693, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8095h13b14                | 8095h13b14                | 0.5726	True
# 0301                      | 0301                      | 0.9950	True
# 2801                      | 2801                      | 1.0000	True
# 3603                      | 3603                      | 0.9734	True
# 2703                      | 2703                      | 1.0000	True
# --------------------------------------------------------------------------------
# end the training

# %% [markdown]
# # 3. TPS-ResNet-BiLSTM-Attn.pth

# %%
args = argparse.Namespace(
    train_data = "../datasets/forTrainingData/train",
    valid_data = "../datasets/forTrainingData/val",
    select_data = "01-02-03",
    batch_ratio = "0.3-0.3-0.4",
    Transformation = "TPS",
    FeatureExtraction = "ResNet",
    SequenceModeling = "BiLSTM",
    Prediction = "Attn",
    saved_model = "models/TPS-ResNet-BiLSTM-Attn.pth",
    FT = True,
    manualSeed = 213,
    
    # Add arg for Training
    num_gpu = None,
    exp_name = None,
    workers = 0,
    batch_size = 192,
    data_filtering_off = None,
    imgH = 32,
    imgW = 100,
    num_iter = 5000,
    valInterval = 100, 
    adam = None,
    lr = 1,
    beta1 = 0.9,
    rho = 0.95,
    eps = 1e-8,
    grad_clip = 5,
    baiduCTC = None,
    total_data_usage_ratio = "1.0",
    batch_max_length = 25,
    rgb = None,
    sensitive = None,
    PAD = None,
    num_fiducial = 20,
    input_channel = 1,
    output_channel = 512,
    hidden_size = 256,
    character = '0123456789abcdefghijklmnopqrstuvwxyz'
    
)

# %%
opt = args

if not opt.exp_name:
    opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
    opt.exp_name += f'-Seed{opt.manualSeed}'
    # print(opt.exp_name)

os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

""" vocab / character number configuration """
if opt.sensitive:
    # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

""" Seed and GPU setting """
# print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
torch.cuda.manual_seed(opt.manualSeed)

cudnn.benchmark = True
cudnn.deterministic = True
opt.num_gpu = torch.cuda.device_count()
# print('device count', opt.num_gpu)
if opt.num_gpu > 1:
    print('------ Use multi-GPU setting ------')
    print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
    # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
    opt.workers = opt.workers * opt.num_gpu
    opt.batch_size = opt.batch_size * opt.num_gpu

    """ previous version
    print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
    opt.batch_size = opt.batch_size * opt.num_gpu
    print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
    If you dont care about it, just commnet out these line.)
    opt.num_iter = int(opt.num_iter / opt.num_gpu)
    """

train(opt)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ../datasets/forTrainingData/train
# opt.select_data: ['01', '02', '03']
# opt.batch_ratio: ['0.3', '0.3', '0.4']
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 01
# sub-directory:	/01	 num samples: 2989
# num total samples of 01: 2989 x 1.0 (total_data_usage_ratio) = 2989
# num samples of 01 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 02
# sub-directory:	/02	 num samples: 2872
# num total samples of 02: 2872 x 1.0 (total_data_usage_ratio) = 2872
# num samples of 02 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 03
# sub-directory:	/03	 num samples: 119
# num total samples of 03: 119 x 1.0 (total_data_usage_ratio) = 119
# num samples of 03 per batch: 192 x 0.4 (batch_ratio) = 77
# --------------------------------------------------------------------------------
# Total_batch_size: 58+58+77 = 193
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/val	 dataset: /
# sub-directory:	/01	 num samples: 747
# sub-directory:	/02	 num samples: 718
# sub-directory:	/03	 num samples: 31
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 38 25 TPS ResNet BiLSTM Attn
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# loading pretrained model from models/TPS-ResNet-BiLSTM-Attn.pth
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=40, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Attention(
#       (attention_cell): AttentionCell(
#         (i2h): Linear(in_features=256, out_features=256, bias=False)
#         (h2h): Linear(in_features=256, out_features=256, bias=True)
#         (score): Linear(in_features=256, out_features=1, bias=False)
#         (rnn): LSTMCell(294, 256)
#       )
#       (generator): Linear(in_features=256, out_features=38, bias=True)
#     )
#   )
# )
# Trainable params num :  49555182
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# train_data: ../datasets/forTrainingData/train
# valid_data: ../datasets/forTrainingData/val
# select_data: ['01', '02', '03']
# batch_ratio: ['0.3', '0.3', '0.4']
# Transformation: TPS
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: Attn
# saved_model: models/TPS-ResNet-BiLSTM-Attn.pth
# FT: True
# manualSeed: 213
# num_gpu: 1
# exp_name: TPS-ResNet-BiLSTM-Attn-Seed213
# workers: 0
# batch_size: 193
# data_filtering_off: None
# imgH: 32
# imgW: 100
# num_iter: 5000
# valInterval: 100
# adam: None
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: None
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# rgb: None
# sensitive: None
# PAD: None
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# num_class: 38
# ---------------------------------------
# [1/5000] Train loss: 3.32478, Valid loss: 2.45784, Elapsed_time: 4.41351
# Current_accuracy : 13.703, Current_norm_ED  : 0.47
# Best_accuracy    : 13.703, Best_norm_ED     : 0.47
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995c44f29                 | 9934442299                | 0.0054	False
# 8108b61307                | 8038611091111111110000000 | 0.0000	False
# 8094h15b11                | 2444151111111144111111111 | 0.0000	False
# 8094h13b08                | 2440000000000000000000000 | 0.0000	False
# 5301                      | 5301                      | 0.4366	True
# --------------------------------------------------------------------------------
# [100/5000] Train loss: 0.21018, Valid loss: 0.10737, Elapsed_time: 99.48005
# Current_accuracy : 89.840, Current_norm_ED  : 0.98
# Best_accuracy    : 89.840, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3604                      | 3504                      | 0.6415	False
# 8093f12732                | 8093f12732                | 0.8972	True
# 3601                      | 3601                      | 0.7747	True
# 7002                      | 7002                      | 0.9945	True
# 9012a31a46                | 9012a31a46                | 0.4944	True
# --------------------------------------------------------------------------------
# [200/5000] Train loss: 0.03821, Valid loss: 0.09469, Elapsed_time: 187.78420
# Current_accuracy : 91.310, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1311y21d34                | 1311y21d34                | 0.9143	True
# 994c50a03                 | 994c50a03                 | 0.9619	True
# 8094g14v04                | 8094g14v04                | 0.8863	True
# 994e43t09                 | 994e43t09                 | 0.9334	True
# 9012e31f57                | 9012e31f57                | 0.8469	True
# --------------------------------------------------------------------------------
# [300/5000] Train loss: 0.02239, Valid loss: 0.11060, Elapsed_time: 274.61122
# Current_accuracy : 90.441, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.9985	True
# 995c42a18                 | 995c42a18                 | 0.9940	True
# 6902                      | 6902                      | 0.9910	True
# 5301                      | 5301                      | 0.9993	True
# 9207                      | 9207                      | 0.9960	True
# --------------------------------------------------------------------------------
# [400/5000] Train loss: 0.01537, Valid loss: 0.10349, Elapsed_time: 362.19293
# Current_accuracy : 90.976, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e32a70                 | 995e32a70                 | 0.9549	True
# c1051b6a10                | c1051b6a10                | 0.8486	True
# 4802                      | 4802                      | 0.9987	True
# 8109b42g26                | 8109b42g26                | 0.9879	True
# 6501                      | 6501                      | 0.9942	True
# --------------------------------------------------------------------------------
# [500/5000] Train loss: 0.01115, Valid loss: 0.11052, Elapsed_time: 448.35274
# Current_accuracy : 90.909, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995b13g49                 | 995b13949                 | 0.6059	False
# 983e42b50                 | 983e42b50                 | 0.9895	True
# 8094e42a07                | 8094e42a07                | 0.9860	True
# 8094t14g16                | 8094t14g46                | 0.3668	False
# 9102s31b10                | 9012831g10                | 0.7643	False
# --------------------------------------------------------------------------------
# [600/5000] Train loss: 0.00651, Valid loss: 0.12752, Elapsed_time: 534.84108
# Current_accuracy : 91.043, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8203                      | 8203                      | 0.9994	True
# 5301                      | 5301                      | 0.9995	True
# 994f92a05                 | 994f92a05                 | 0.9915	True
# 9012f51a89                | 9012f51a89                | 0.9715	True
# 1501                      | 1501                      | 0.6462	True
# --------------------------------------------------------------------------------
# [700/5000] Train loss: 0.00728, Valid loss: 0.12249, Elapsed_time: 621.96170
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3701                      | 3701                      | 0.9997	True
# 8093e51h58                | 8093e51h58                | 0.5136	True
# 1801                      | 1801                      | 0.9997	True
# 983e33f42                 | 983e33f42                 | 0.9965	True
# 995e36317                 | 995e35317                 | 0.9142	False
# --------------------------------------------------------------------------------
# [800/5000] Train loss: 0.01874, Valid loss: 0.11292, Elapsed_time: 708.70315
# Current_accuracy : 90.575, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# b109s23f42                | 8109s23f42                | 0.9795	False
# 4502                      | 4502                      | 0.9987	True
# 9102s31b10                | 9012s31g10                | 0.6169	False
# 8108f52b12                | 8108f52b12                | 0.9891	True
# 8095a81v06                | 8095a81v06                | 0.9754	True
# --------------------------------------------------------------------------------
# [900/5000] Train loss: 0.00599, Valid loss: 0.12394, Elapsed_time: 795.47225
# Current_accuracy : 90.107, Current_norm_ED  : 0.98
# Best_accuracy    : 91.310, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9701                      | 9701                      | 0.9997	True
# 983f11a51                 | 983f11a51                 | 0.9946	True
# 5301                      | 5301                      | 0.9998	True
# 8108b61307                | 8108b61307                | 0.9789	True
# 8109b38a10                | 8109b38a10                | 0.9980	True
# --------------------------------------------------------------------------------
# [1000/5000] Train loss: 0.00310, Valid loss: 0.11958, Elapsed_time: 882.26054
# Current_accuracy : 91.845, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8601                      | 8601                      | 0.9997	True
# 5002                      | 5002                      | 1.0000	True
# 9604                      | 9604                      | 0.9944	True
# 8094b56r03                | 8094b58r03                | 0.4744	False
# 4902                      | 4902                      | 0.9997	True
# --------------------------------------------------------------------------------
# [1100/5000] Train loss: 0.00292, Valid loss: 0.13087, Elapsed_time: 969.61107
# Current_accuracy : 91.778, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2801                      | 2801                      | 0.9998	True
# 8094e42a07                | 8094e42a07                | 0.9995	True
# 995c44a09                 | 995c44a09                 | 0.9989	True
# 9012e31b68                | 9012e31b68                | 0.9963	True
# 5301                      | 5301                      | 0.9999	True
# --------------------------------------------------------------------------------
# [1200/5000] Train loss: 0.00323, Valid loss: 0.13156, Elapsed_time: 1056.70369
# Current_accuracy : 91.377, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b15f15                | 8108b15f15                | 0.9988	True
# 8108b11h41                | 8108d11h41                | 0.8278	False
# 8094d15a01                | 8094d15a01                | 0.9810	True
# 8093s11r05                | 8093s11r05                | 0.9811	True
# 8093f12732                | 8093f12732                | 0.9952	True
# --------------------------------------------------------------------------------
# [1300/5000] Train loss: 0.00205, Valid loss: 0.13673, Elapsed_time: 1147.04762
# Current_accuracy : 90.441, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093a21307                | 8093a21307                | 0.9987	True
# 3902                      | 3902                      | 0.9981	True
# 5603                      | 5603                      | 0.7414	True
# 983s17k49                 | 983s17k49                 | 0.9984	True
# 5301                      | 5301                      | 0.9999	True
# --------------------------------------------------------------------------------
# [1400/5000] Train loss: 0.00117, Valid loss: 0.14224, Elapsed_time: 1233.40414
# Current_accuracy : 90.976, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9604                      | 9604                      | 0.9998	True
# 995b17r09                 | 995b17r09                 | 0.9997	True
# 8801                      | 8801                      | 0.9999	True
# 8093d32a17                | 8093d32a17                | 0.9989	True
# 8604                      | 8604                      | 0.9995	True
# --------------------------------------------------------------------------------
# [1500/5000] Train loss: 0.00096, Valid loss: 0.13713, Elapsed_time: 1320.18516
# Current_accuracy : 90.909, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012e32a19                | 9012e32a19                | 0.9995	True
# 5501                      | 5501                      | 1.0000	True
# 8094s20b51                | 8094s20b51                | 0.9871	True
# 2803                      | 2803                      | 0.9999	True
# 5401                      | 5401                      | 0.9990	True
# --------------------------------------------------------------------------------
# [1600/5000] Train loss: 0.00052, Valid loss: 0.15154, Elapsed_time: 1407.23981
# Current_accuracy : 91.711, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983s11b41                 | 983s11b41                 | 0.9975	True
# 8093d41303                | 8093d41303                | 0.9989	True
# 9012e31a17                | 9012e31a17                | 0.9951	True
# 3101                      | 3101                      | 0.9999	True
# 2703                      | 2703                      | 1.0000	True
# --------------------------------------------------------------------------------
# [1700/5000] Train loss: 0.00029, Valid loss: 0.14857, Elapsed_time: 1493.88348
# Current_accuracy : 91.511, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0002                      | 0002                      | 1.0000	True
# 983h13b14                 | 983h13b14                 | 0.9995	True
# 6103                      | 6103                      | 0.9999	True
# 9012f11a20                | 9012f11a20                | 0.9982	True
# 983b75a11                 | 983b75a11                 | 0.9987	True
# --------------------------------------------------------------------------------
# [1800/5000] Train loss: 0.00023, Valid loss: 0.14820, Elapsed_time: 1582.04535
# Current_accuracy : 91.043, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2801                      | 2801                      | 1.0000	True
# 3101                      | 3101                      | 0.9999	True
# 8108f41310                | 8108f41310                | 0.9976	True
# 9401                      | 9401                      | 1.0000	True
# 0705                      | 0705                      | 1.0000	True
# --------------------------------------------------------------------------------
# [1900/5000] Train loss: 0.00044, Valid loss: 0.15607, Elapsed_time: 1668.83025
# Current_accuracy : 91.310, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6303                      | 6303                      | 0.9994	True
# 8093a21a23                | 8093a21a23                | 0.9995	True
# 6203                      | 6803                      | 0.9943	False
# 5301                      | 5301                      | 0.9999	True
# 8093a21307                | 8093a21307                | 0.9997	True
# --------------------------------------------------------------------------------
# [2000/5000] Train loss: 0.00029, Valid loss: 0.16191, Elapsed_time: 1756.01051
# Current_accuracy : 91.243, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8604                      | 8604                      | 0.9999	True
# 8094h15b04                | 8094h15b04                | 0.9996	True
# 5001                      | 5001                      | 0.9997	True
# 995e33a12                 | 995e33a12                 | 0.9999	True
# 8094d11a11                | 8094d11a11                | 0.9998	True
# --------------------------------------------------------------------------------
# [2100/5000] Train loss: 0.00028, Valid loss: 0.15713, Elapsed_time: 1842.29781
# Current_accuracy : 91.110, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e33a12                 | 995e33a12                 | 0.9999	True
# 8093f12327                | 8093f12327                | 0.9997	True
# 8601                      | 8601                      | 0.9999	True
# 4901                      | 4901                      | 1.0000	True
# 4003                      | 4003                      | 0.9999	True
# --------------------------------------------------------------------------------
# [2200/5000] Train loss: 0.00013, Valid loss: 0.15145, Elapsed_time: 1930.84300
# Current_accuracy : 91.377, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3101                      | 3101                      | 1.0000	True
# 0502                      | 0502                      | 1.0000	True
# 1601                      | 1601                      | 0.9845	True
# 8109s20a15                | 8109s20a15                | 0.9998	True
# 8094b59g39                | 8094b59g39                | 0.8366	True
# --------------------------------------------------------------------------------
# [2300/5000] Train loss: 0.00011, Valid loss: 0.15700, Elapsed_time: 2017.06626
# Current_accuracy : 91.243, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994e43t09                 | 994e43t09                 | 0.9912	True
# 995e24r04                 | 995e24r04                 | 0.9996	True
# 8108f42b12                | 8108f52b12                | 0.9905	False
# 983b74a09                 | 983b74a09                 | 0.9988	True
# 983s17t54                 | 983s17t54                 | 0.9996	True
# --------------------------------------------------------------------------------
# [2400/5000] Train loss: 0.00037, Valid loss: 0.15383, Elapsed_time: 2103.21061
# Current_accuracy : 91.377, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2003                      | 2003                      | 1.0000	True
# 1003                      | 1003                      | 0.9999	True
# 0103                      | 0103                      | 1.0000	True
# 3804                      | 3804                      | 0.9994	True
# 2302                      | 2302                      | 0.9901	True
# --------------------------------------------------------------------------------
# [2500/5000] Train loss: 0.00019, Valid loss: 0.15818, Elapsed_time: 2190.04814
# Current_accuracy : 91.644, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995h13b08                 | 995h13b08                 | 0.9999	True
# 8109t21b16                | 8109t21b16                | 0.9999	True
# 9102                      | 9102                      | 1.0000	True
# 6503                      | 6503                      | 0.9999	True
# 8094h12b18                | 8094h12b18                | 0.9998	True
# --------------------------------------------------------------------------------
# [2600/5000] Train loss: 0.00230, Valid loss: 0.15306, Elapsed_time: 2278.15202
# Current_accuracy : 91.511, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7502                      | 7502                      | 0.9999	True
# 0705                      | 0705                      | 0.9999	True
# 8901                      | 8901                      | 1.0000	True
# 0103                      | 0103                      | 0.9978	True
# 8601                      | 8601                      | 0.9999	True
# --------------------------------------------------------------------------------
# [2700/5000] Train loss: 0.00095, Valid loss: 0.26977, Elapsed_time: 2365.00606
# Current_accuracy : 89.840, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109e42m68                | 8109e42m68                | 0.9993	True
# 9012e31f57                | 9012e31f57                | 0.9824	True
# 9801                      | 9801                      | 0.9999	True
# 9012e31f57                | 9012e31f57                | 0.9918	True
# 1501                      | 1501                      | 1.0000	True
# --------------------------------------------------------------------------------
# [2800/5000] Train loss: 0.00195, Valid loss: 0.15319, Elapsed_time: 2451.66661
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093t15f31                | 8093t15f31                | 0.9928	True
# 983l13t51                 | 983l13t51                 | 0.9962	True
# 4501                      | 4501                      | 0.9999	True
# 3101                      | 3101                      | 0.9999	True
# 8094bs8f48                | 8094b53f48                | 0.9963	False
# --------------------------------------------------------------------------------
# [2900/5000] Train loss: 0.00167, Valid loss: 0.14783, Elapsed_time: 2538.39119
# Current_accuracy : 91.043, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4802                      | 4802                      | 0.9999	True
# 983c33f23                 | 983c33f23                 | 0.9996	True
# 1003                      | 1003                      | 0.9997	True
# 0104                      | 0104                      | 0.9999	True
# 3604                      | 3504                      | 0.9679	False
# --------------------------------------------------------------------------------
# [3000/5000] Train loss: 0.00045, Valid loss: 0.14442, Elapsed_time: 2625.10650
# Current_accuracy : 91.377, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b11h41                | 8108d11h41                | 0.9962	False
# 995b17r09                 | 995b17r09                 | 0.9996	True
# 6803                      | 6803                      | 0.9719	True
# 8093g12a33                | 8093f12a33                | 0.8211	False
# 2604                      | 2604                      | 0.9907	True
# --------------------------------------------------------------------------------
# [3100/5000] Train loss: 0.00024, Valid loss: 0.14584, Elapsed_time: 2711.89866
# Current_accuracy : 91.711, Current_norm_ED  : 0.98
# Best_accuracy    : 91.845, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5804                      | 5804                      | 0.9998	True
# 2604                      | 2604                      | 0.9999	True
# 7901                      | 7901                      | 1.0000	True
# 8093f12j25                | 8093f12j25                | 0.9987	True
# 995b17b32                 | 995b12b32                 | 0.3902	False
# --------------------------------------------------------------------------------
# [3200/5000] Train loss: 0.00020, Valid loss: 0.14955, Elapsed_time: 2798.72021
# Current_accuracy : 91.912, Current_norm_ED  : 0.99
# Best_accuracy    : 91.912, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9901                      | 9901                      | 1.0000	True
# 8109b22d83                | 8109b22d03                | 0.9849	False
# 994c51a20                 | 994c51a20                 | 0.9998	True
# 8108b61g12                | 8108b61612                | 0.7659	False
# 5101                      | 5001                      | 0.9999	False
# --------------------------------------------------------------------------------
# [3300/5000] Train loss: 0.00016, Valid loss: 0.15414, Elapsed_time: 2886.04279
# Current_accuracy : 91.644, Current_norm_ED  : 0.98
# Best_accuracy    : 91.912, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094e31j16                | 8094e31j16                | 0.9996	True
# 5603                      | 5603                      | 0.9995	True
# c1051b1a04                | c1051b1a04                | 0.9989	True
# 8094h15b11                | 8094h15b11                | 0.9969	True
# 3601                      | 3601                      | 0.9961	True
# --------------------------------------------------------------------------------
# [3400/5000] Train loss: 0.00037, Valid loss: 0.15699, Elapsed_time: 2972.67283
# Current_accuracy : 91.778, Current_norm_ED  : 0.99
# Best_accuracy    : 91.912, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5001                      | 5001                      | 0.9999	True
# 8108f52b07                | 8108f52b07                | 0.9991	True
# 994c32a14                 | 994c32a14                 | 0.9996	True
# 995e36317                 | 995e35317                 | 0.9986	False
# 8109h23b19                | 8109h23b19                | 0.9990	True
# --------------------------------------------------------------------------------
# [3500/5000] Train loss: 0.00023, Valid loss: 0.15389, Elapsed_time: 3059.44123
# Current_accuracy : 92.045, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4001                      | 4001                      | 0.9998	True
# 8801                      | 8801                      | 0.9998	True
# 1003                      | 1003                      | 0.9998	True
# 0103                      | 0103                      | 1.0000	True
# 5502                      | 0502                      | 0.5068	False
# --------------------------------------------------------------------------------
# [3600/5000] Train loss: 0.00022, Valid loss: 0.15185, Elapsed_time: 3146.60813
# Current_accuracy : 91.845, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9301                      | 9301                      | 0.9949	True
# 995e24r01                 | 995e24r01                 | 0.9997	True
# 2402                      | 2402                      | 0.9986	True
# 983b72a11                 | 983b72a11                 | 0.9995	True
# 8093f42306                | 8093f42306                | 0.9965	True
# --------------------------------------------------------------------------------
# [3700/5000] Train loss: 0.00021, Valid loss: 0.15202, Elapsed_time: 3233.12207
# Current_accuracy : 91.644, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1202                      | 1202                      | 0.9999	True
# 8094d21a05                | 8094d21a05                | 0.9995	True
# 4801                      | 4801                      | 0.9918	True
# 8093a21a23                | 8093a21a23                | 0.9966	True
# 8108f52b12                | 8108f52b12                | 0.9998	True
# --------------------------------------------------------------------------------
# [3800/5000] Train loss: 0.00015, Valid loss: 0.15202, Elapsed_time: 3319.93892
# Current_accuracy : 91.778, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e35317                 | 995e35317                 | 0.9814	True
# 8109e42m70                | 8109e42m70                | 0.9998	True
# 4301                      | 4301                      | 1.0000	True
# 983b14b36                 | 983b14b36                 | 0.9999	True
# 7002                      | 7002                      | 1.0000	True
# --------------------------------------------------------------------------------
# [3900/5000] Train loss: 0.00007, Valid loss: 0.15727, Elapsed_time: 3406.57196
# Current_accuracy : 91.912, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4802                      | 4802                      | 1.0000	True
# 5603                      | 5603                      | 0.9830	True
# 7902                      | 7902                      | 0.9999	True
# 8109h15b23                | 8109h15b23                | 0.9984	True
# 8093b12f24                | 8093b12f24                | 0.9995	True
# --------------------------------------------------------------------------------
# [4000/5000] Train loss: 0.00006, Valid loss: 0.15842, Elapsed_time: 3493.19422
# Current_accuracy : 91.979, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094h22f27                | 8094h22f27                | 0.9997	True
# 4602                      | 4602                      | 1.0000	True
# 983h13b14                 | 983h13b14                 | 0.9999	True
# 983e33t54                 | 983e33t54                 | 0.9997	True
# 995b17a17                 | 995b17a17                 | 0.9998	True
# --------------------------------------------------------------------------------
# [4100/5000] Train loss: 0.00064, Valid loss: 0.15675, Elapsed_time: 3579.94009
# Current_accuracy : 91.912, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0001                      | 0001                      | 1.0000	True
# 9901                      | 9901                      | 1.0000	True
# 2801                      | 2801                      | 1.0000	True
# 983s17t54                 | 983s17t54                 | 0.9998	True
# 8093b16740                | 8093b16f40                | 0.9988	False
# --------------------------------------------------------------------------------
# [4200/5000] Train loss: 0.00518, Valid loss: 0.14292, Elapsed_time: 3667.60820
# Current_accuracy : 91.176, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8901                      | 8901                      | 1.0000	True
# 2803                      | 2803                      | 0.9999	True
# 8094e28f43                | 8094e28f43                | 0.9979	True
# 1202                      | 1202                      | 0.9998	True
# 8093f12327                | 8093f12327                | 0.9987	True
# --------------------------------------------------------------------------------
# [4300/5000] Train loss: 0.00390, Valid loss: 0.13458, Elapsed_time: 3754.27890
# Current_accuracy : 91.310, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36311                 | 995e36311                 | 0.9994	True
# 3701                      | 3701                      | 1.0000	True
# 9503                      | 9503                      | 1.0000	True
# 3001                      | 3001                      | 1.0000	True
# 9012f31qa9                | 9012f31qa9                | 0.6177	True
# --------------------------------------------------------------------------------
# [4400/5000] Train loss: 0.00101, Valid loss: 0.14069, Elapsed_time: 3840.93334
# Current_accuracy : 91.243, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093a21307                | 8093a21307                | 0.9996	True
# 4002                      | 4002                      | 1.0000	True
# 4202                      | 4202                      | 1.0000	True
# 8201                      | 8201                      | 1.0000	True
# 4601                      | 4601                      | 0.9999	True
# --------------------------------------------------------------------------------
# [4500/5000] Train loss: 0.00034, Valid loss: 0.14419, Elapsed_time: 3927.88562
# Current_accuracy : 91.511, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2801                      | 2801                      | 1.0000	True
# 8094d21a05                | 8094d21a05                | 0.9717	True
# 4602                      | 4602                      | 0.9999	True
# 2604                      | 2604                      | 1.0000	True
# 4502                      | 4502                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4600/5000] Train loss: 0.00015, Valid loss: 0.14763, Elapsed_time: 4014.64212
# Current_accuracy : 91.511, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109s21f45                | 8109s21f45                | 0.9998	True
# 983b15a08                 | 983b15a08                 | 0.9975	True
# 0702                      | 0702                      | 1.0000	True
# 1603                      | 1603                      | 1.0000	True
# 5701                      | 5701                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4700/5000] Train loss: 0.00050, Valid loss: 0.15244, Elapsed_time: 4101.45462
# Current_accuracy : 91.377, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5203                      | 5203                      | 0.9988	True
# 8108b38m51                | 8108b38m51                | 0.9996	True
# 995e36317                 | 995e35317                 | 0.9990	False
# 8094e42a07                | 8094e42a07                | 0.9999	True
# 8094t14g16                | 8094t14g46                | 0.7387	False
# --------------------------------------------------------------------------------
# [4800/5000] Train loss: 0.00035, Valid loss: 0.15432, Elapsed_time: 4188.37632
# Current_accuracy : 91.511, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1003                      | 1003                      | 1.0000	True
# 983c33f22                 | 983c33f22                 | 0.9916	True
# 9012e31b68                | 9012e31b68                | 0.9996	True
# 9012f31a9                 | 9012f31qa9                | 0.9962	False
# 983s11b50                 | 983s11b50                 | 0.9999	True
# --------------------------------------------------------------------------------
# [4900/5000] Train loss: 0.00037, Valid loss: 0.15117, Elapsed_time: 4275.13990
# Current_accuracy : 91.243, Current_norm_ED  : 0.98
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983b74a06                 | 983b74a06                 | 0.9997	True
# 995c44f29                 | 995c44f29                 | 0.6376	True
# 8109h13b18                | 8109h13b18                | 0.9999	True
# 3802                      | 3802                      | 0.9999	True
# 4303                      | 4303                      | 1.0000	True
# --------------------------------------------------------------------------------
# [5000/5000] Train loss: 0.00015, Valid loss: 0.15629, Elapsed_time: 4361.96695
# Current_accuracy : 91.578, Current_norm_ED  : 0.99
# Best_accuracy    : 92.045, Best_norm_ED     : 0.99
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b64312                | 8108b64312                | 0.9991	True
# 8094d21a05                | 8094d21a05                | 0.9998	True
# 8094t43j23                | 8094t43j23                | 0.9996	True
# 982d43h40                 | 982d43h40                 | 0.9997	True
# 995b11t51                 | 995b11f51                 | 0.9938	False
# --------------------------------------------------------------------------------
# end the training

# %% [markdown]
# # 4. TPS-ResNet-BiLSTM-CTC.pth

# %%
args = argparse.Namespace(
    train_data = "../datasets/forTrainingData/train",
    valid_data = "../datasets/forTrainingData/val",
    select_data = "01-02-03",
    batch_ratio = "0.3-0.3-0.4",
    Transformation = "TPS",
    FeatureExtraction = "ResNet",
    SequenceModeling = "BiLSTM",
    Prediction = "CTC",
    saved_model = "models/TPS-ResNet-BiLSTM-CTC.pth",
    FT = True,
    manualSeed = 213,
    
    # Add arg for Training
    num_gpu = None,
    exp_name = None,
    workers = 0,
    batch_size = 192,
    data_filtering_off = None,
    imgH = 32,
    imgW = 100,
    num_iter = 5000,
    valInterval = 100, 
    adam = None,
    lr = 1,
    beta1 = 0.9,
    rho = 0.95,
    eps = 1e-8,
    grad_clip = 5,
    baiduCTC = None,
    total_data_usage_ratio = "1.0",
    batch_max_length = 25,
    rgb = None,
    sensitive = None,
    PAD = None,
    num_fiducial = 20,
    input_channel = 1,
    output_channel = 512,
    hidden_size = 256,
    character = '0123456789abcdefghijklmnopqrstuvwxyz'
    
)

# %%
opt = args

if not opt.exp_name:
    opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
    opt.exp_name += f'-Seed{opt.manualSeed}'
    # print(opt.exp_name)

os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

""" vocab / character number configuration """
if opt.sensitive:
    # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

""" Seed and GPU setting """
# print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
torch.cuda.manual_seed(opt.manualSeed)

cudnn.benchmark = True
cudnn.deterministic = True
opt.num_gpu = torch.cuda.device_count()
# print('device count', opt.num_gpu)
if opt.num_gpu > 1:
    print('------ Use multi-GPU setting ------')
    print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
    # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
    opt.workers = opt.workers * opt.num_gpu
    opt.batch_size = opt.batch_size * opt.num_gpu

    """ previous version
    print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
    opt.batch_size = opt.batch_size * opt.num_gpu
    print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
    If you dont care about it, just commnet out these line.)
    opt.num_iter = int(opt.num_iter / opt.num_gpu)
    """

train(opt)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ../datasets/forTrainingData/train
# opt.select_data: ['01', '02', '03']
# opt.batch_ratio: ['0.3', '0.3', '0.4']
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 01
# sub-directory:	/01	 num samples: 2989
# num total samples of 01: 2989 x 1.0 (total_data_usage_ratio) = 2989
# num samples of 01 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 02
# sub-directory:	/02	 num samples: 2872
# num total samples of 02: 2872 x 1.0 (total_data_usage_ratio) = 2872
# num samples of 02 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 03
# sub-directory:	/03	 num samples: 119
# num total samples of 03: 119 x 1.0 (total_data_usage_ratio) = 119
# num samples of 03 per batch: 192 x 0.4 (batch_ratio) = 77
# --------------------------------------------------------------------------------
# Total_batch_size: 58+58+77 = 193
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/val	 dataset: /
# sub-directory:	/01	 num samples: 747
# sub-directory:	/02	 num samples: 718
# sub-directory:	/03	 num samples: 31
# --------------------------------------------------------------------------------
# model input parameters 32 100 20 1 512 256 37 25 TPS ResNet BiLSTM CTC
# Skip Transformation.LocalizationNetwork.localization_fc2.weight as it is already initialized
# Skip Transformation.LocalizationNetwork.localization_fc2.bias as it is already initialized
# loading pretrained model from models/TPS-ResNet-BiLSTM-CTC.pth
# Model:
# DataParallel(
#   (module): Model(
#     (Transformation): TPS_SpatialTransformerNetwork(
#       (LocalizationNetwork): LocalizationNetwork(
#         (conv): Sequential(
#           (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (6): ReLU(inplace=True)
#           (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (10): ReLU(inplace=True)
#           (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#           (12): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (14): ReLU(inplace=True)
#           (15): AdaptiveAvgPool2d(output_size=1)
#         )
#         (localization_fc1): Sequential(
#           (0): Linear(in_features=512, out_features=256, bias=True)
#           (1): ReLU(inplace=True)
#         )
#         (localization_fc2): Linear(in_features=256, out_features=40, bias=True)
#       )
#       (GridGenerator): GridGenerator()
#     )
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(512, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=37, bias=True)
#   )
# )
# Trainable params num :  48858093
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# train_data: ../datasets/forTrainingData/train
# valid_data: ../datasets/forTrainingData/val
# select_data: ['01', '02', '03']
# batch_ratio: ['0.3', '0.3', '0.4']
# Transformation: TPS
# FeatureExtraction: ResNet
# SequenceModeling: BiLSTM
# Prediction: CTC
# saved_model: models/TPS-ResNet-BiLSTM-CTC.pth
# FT: True
# manualSeed: 213
# num_gpu: 1
# exp_name: TPS-ResNet-BiLSTM-CTC-Seed213
# workers: 0
# batch_size: 193
# data_filtering_off: None
# imgH: 32
# imgW: 100
# num_iter: 5000
# valInterval: 100
# adam: None
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: None
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# rgb: None
# sensitive: None
# PAD: None
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# num_class: 37
# ---------------------------------------
# [1/5000] Train loss: 6.14577, Valid loss: 3.22677, Elapsed_time: 0.88189
# Current_accuracy : 7.487, Current_norm_ED  : 0.38
# Best_accuracy    : 7.487, Best_norm_ED     : 0.38
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3603                      | xo3                       | 0.0261	False
# 8094b20617                | si2269                    | 0.0000	False
# 4001                      | gooj                      | 0.0086	False
# 8109f11a32                | bogfuaie                  | 0.0000	False
# 3701                      | 3701                      | 0.7318	True
# --------------------------------------------------------------------------------
# [100/5000] Train loss: 0.35205, Valid loss: 0.15922, Elapsed_time: 84.52140
# Current_accuracy : 83.757, Current_norm_ED  : 0.97
# Best_accuracy    : 83.757, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012e31f57                | 9012e3f57                 | 0.2481	False
# 983h13b14                 | 983h13b14                 | 0.4668	True
# 9012f41a18                | 9012f41a18                | 0.3637	True
# 2803                      | 2803                      | 0.8617	True
# 6303                      | 6303                      | 0.9625	True
# --------------------------------------------------------------------------------
# [200/5000] Train loss: 0.08105, Valid loss: 0.13982, Elapsed_time: 168.92816
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.032, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3902                      | 3902                      | 0.8957	True
# 6103                      | 6103                      | 0.5992	True
# 8705                      | 8705                      | 0.3698	True
# 7002                      | 7002                      | 0.9800	True
# 8109e41f40                | 8109e41f40                | 0.6309	True
# --------------------------------------------------------------------------------
# [300/5000] Train loss: 0.04973, Valid loss: 0.12593, Elapsed_time: 253.08819
# Current_accuracy : 89.305, Current_norm_ED  : 0.98
# Best_accuracy    : 89.305, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995h13b08                 | 995h13b08                 | 0.9091	True
# 6103                      | 6103                      | 0.9457	True
# 9012e32a29                | 9012e32a29                | 0.9205	True
# 9102                      | 9102                      | 0.9611	True
# 983b12a48                 | 983b12a42                 | 0.2660	False
# --------------------------------------------------------------------------------
# [400/5000] Train loss: 0.03534, Valid loss: 0.12686, Elapsed_time: 337.48592
# Current_accuracy : 89.305, Current_norm_ED  : 0.98
# Best_accuracy    : 89.305, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b59g39                | 8094b59g39                | 0.5060	True
# 3701                      | 3701                      | 0.9961	True
# 983h17b07                 | 983h19b09                 | 0.1109	False
# 6801                      | 6801                      | 0.9961	True
# 8094b56r03                | 8094b56r03                | 0.2549	True
# --------------------------------------------------------------------------------
# [500/5000] Train loss: 0.02690, Valid loss: 0.11865, Elapsed_time: 421.61431
# Current_accuracy : 90.107, Current_norm_ED  : 0.98
# Best_accuracy    : 90.107, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5301                      | 5301                      | 0.8296	True
# 983s23g63                 | 983s23g63                 | 0.9568	True
# 8109h15b23                | 8109h15b23                | 0.7048	True
# 983s11b49                 | a83s11b49                 | 0.6869	False
# 8094s20a29                | 8094st0a29                | 0.3351	False
# --------------------------------------------------------------------------------
# [600/5000] Train loss: 0.01969, Valid loss: 0.11770, Elapsed_time: 505.75891
# Current_accuracy : 90.374, Current_norm_ED  : 0.98
# Best_accuracy    : 90.374, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9108f41b33                | 8108f41b33                | 0.5800	False
# 5604                      | 5604                      | 0.9965	True
# 3001                      | 3001                      | 0.9996	True
# 7002                      | 7002                      | 0.9793	True
# 8094t13f32                | 8094t13f32                | 0.5768	True
# --------------------------------------------------------------------------------
# [700/5000] Train loss: 0.01545, Valid loss: 0.12784, Elapsed_time: 590.15055
# Current_accuracy : 90.575, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9301                      | 9301                      | 0.6551	True
# 983e21g11                 | 983e21g11                 | 0.8998	True
# 8108f41b33                | 8108f41b33                | 0.6156	True
# 8094s13b45                | 8094s13b45                | 0.9606	True
# 3601                      | 3601                      | 0.9534	True
# --------------------------------------------------------------------------------
# [800/5000] Train loss: 0.01222, Valid loss: 0.12820, Elapsed_time: 674.70391
# Current_accuracy : 90.374, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9501                      | 9501                      | 0.5206	True
# 8109t21b16                | 8109t21b16                | 0.4794	True
# 8094h12b18                | 8094h12b18                | 0.9229	True
# 7002                      | 7002                      | 0.9970	True
# 983l13t51                 | 983l13t51                 | 0.6704	True
# --------------------------------------------------------------------------------
# [900/5000] Train loss: 0.00972, Valid loss: 0.13223, Elapsed_time: 758.79569
# Current_accuracy : 90.040, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093a21307                | 8093a21307                | 0.5125	True
# 4003                      | 4003                      | 0.9817	True
# 8094h21f40                | 8094h21f40                | 0.3062	True
# 982d43h40                 | 982d43h40                 | 0.5520	True
# 994e43t09                 | 994e43t09                 | 0.8480	True
# --------------------------------------------------------------------------------
# [1000/5000] Train loss: 0.00760, Valid loss: 0.14326, Elapsed_time: 842.46669
# Current_accuracy : 90.241, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4101                      | 4101                      | 0.9954	True
# 995e36t39                 | 995e36t39                 | 0.9625	True
# 6103                      | 6103                      | 0.9751	True
# 983e42f22                 | 983e41f22                 | 0.8977	False
# 2703                      | 2703                      | 0.9997	True
# --------------------------------------------------------------------------------
# [1100/5000] Train loss: 0.00636, Valid loss: 0.14116, Elapsed_time: 926.25080
# Current_accuracy : 90.575, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2602                      | 2602                      | 0.9701	True
# 983e42726                 | 983e42726                 | 0.7570	True
# 995b17a18                 | 995b17a18                 | 0.6112	True
# 7503                      | 7503                      | 0.9993	True
# 8603                      | 8603                      | 0.9959	True
# --------------------------------------------------------------------------------
# [1200/5000] Train loss: 0.00559, Valid loss: 0.14292, Elapsed_time: 1009.82051
# Current_accuracy : 89.372, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109b38a10                | 8109b38a10                | 0.5725	True
# 983h17b06                 | 983h17b06                 | 0.7600	True
# 6201                      | 6201                      | 0.7546	True
# 6702                      | 6700                      | 0.8985	False
# 8108f41310                | 8108f41310                | 0.8738	True
# --------------------------------------------------------------------------------
# [1300/5000] Train loss: 0.00428, Valid loss: 0.14783, Elapsed_time: 1093.42563
# Current_accuracy : 90.508, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c50a20                 | 994c50a20                 | 0.9397	True
# 1803                      | 1803                      | 0.9817	True
# 7902                      | 7902                      | 0.9977	True
# 6803                      | 6803                      | 0.9936	True
# 7002                      | 7002                      | 0.9967	True
# --------------------------------------------------------------------------------
# [1400/5000] Train loss: 0.00379, Valid loss: 0.14872, Elapsed_time: 1177.23721
# Current_accuracy : 90.241, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8095a81v06                | 8095a81v06                | 0.3976	True
# 8109b42a11                | 8109b42a11                | 0.5544	True
# 8094b61j58                | 8094b60j58                | 0.8428	False
# 8094bs8f48                | 8094b53f48                | 0.7940	False
# 9703                      | 9903                      | 0.9966	False
# --------------------------------------------------------------------------------
# [1500/5000] Train loss: 0.00304, Valid loss: 0.15337, Elapsed_time: 1260.96126
# Current_accuracy : 90.107, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1311y21d33                | 1311y21d33                | 0.7746	True
# 995h13b08                 | 995h13b08                 | 0.7459	True
# 995b14r09                 | 995b17r09                 | 0.9397	False
# 983h17b07                 | 983h17b07                 | 0.9578	True
# 3004                      | 3004                      | 0.9859	True
# --------------------------------------------------------------------------------
# [1600/5000] Train loss: 0.00281, Valid loss: 0.14852, Elapsed_time: 1344.50874
# Current_accuracy : 89.973, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1603                      | 1603                      | 0.8972	True
# 983e21g11                 | 983e21g11                 | 0.9496	True
# 8109e51h38                | 8109e51h38                | 0.9811	True
# 3801                      | 3801                      | 0.9965	True
# 995e35318                 | 995e35318                 | 0.9284	True
# --------------------------------------------------------------------------------
# [1700/5000] Train loss: 0.00214, Valid loss: 0.15641, Elapsed_time: 1428.18815
# Current_accuracy : 90.307, Current_norm_ED  : 0.98
# Best_accuracy    : 90.575, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8604                      | 8604                      | 0.9981	True
# 8094s20a29                | 8094s20a29                | 0.7574	True
# 3004                      | 3004                      | 0.9691	True
# 9012n15b17                | 9012h15b17                | 0.7240	False
# 983h17b06                 | 983h17b06                 | 0.5125	True
# --------------------------------------------------------------------------------
# [1800/5000] Train loss: 0.00147, Valid loss: 0.16093, Elapsed_time: 1512.18197
# Current_accuracy : 90.775, Current_norm_ED  : 0.98
# Best_accuracy    : 90.775, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7801                      | 7801                      | 0.9888	True
# 9012e32a19                | 9012e32a19                | 0.7772	True
# 8404                      | 8404                      | 0.9997	True
# 3004                      | 3004                      | 0.9429	True
# 983s24j60                 | 983d24j60                 | 0.6266	False
# --------------------------------------------------------------------------------
# [1900/5000] Train loss: 0.00178, Valid loss: 0.16555, Elapsed_time: 1596.52604
# Current_accuracy : 90.842, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994e43t09                 | 994e43t09                 | 0.9566	True
# 7002                      | 7002                      | 0.7880	True
# 0001                      | 0001                      | 0.8902	True
# 9301                      | 9301                      | 0.9610	True
# 5401                      | 5401                      | 0.9072	True
# --------------------------------------------------------------------------------
# [2000/5000] Train loss: 0.00126, Valid loss: 0.16687, Elapsed_time: 1680.93719
# Current_accuracy : 90.241, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012e31a31                | 9012e31a31                | 0.5197	True
# 4504                      | 4604                      | 0.5520	False
# 8109b42a11                | 8109b42a11                | 0.4022	True
# 2803                      | 2803                      | 0.9997	True
# 3001                      | 3001                      | 0.9995	True
# --------------------------------------------------------------------------------
# [2100/5000] Train loss: 0.00130, Valid loss: 0.16972, Elapsed_time: 1764.83123
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 335s13m10                 | 995s16m10                 | 0.7718	False
# 1202                      | 1202                      | 0.9937	True
# 3603                      | 3603                      | 0.9987	True
# 1103                      | 1103                      | 0.9992	True
# 8108s17a28                | 8108s17a28                | 0.4590	True
# --------------------------------------------------------------------------------
# [2200/5000] Train loss: 0.00163, Valid loss: 0.15796, Elapsed_time: 1848.47325
# Current_accuracy : 90.575, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6803                      | 6803                      | 0.8425	True
# 9301                      | 9301                      | 0.9511	True
# 983b72a11                 | 983b72a11                 | 0.9967	True
# 8802                      | 8802                      | 0.6775	True
# 983e21g11                 | 983e21g11                 | 0.9930	True
# --------------------------------------------------------------------------------
# [2300/5000] Train loss: 0.00083, Valid loss: 0.15916, Elapsed_time: 1931.99448
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b20617                | 8094b20617                | 0.9070	True
# 6103                      | 6103                      | 0.9967	True
# 0103                      | 0103                      | 0.6907	True
# 8602                      | 8602                      | 0.9861	True
# 4401                      | 4401                      | 0.9999	True
# --------------------------------------------------------------------------------
# [2400/5000] Train loss: 0.00099, Valid loss: 0.17454, Elapsed_time: 2015.64258
# Current_accuracy : 89.773, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5301                      | 5301                      | 0.9937	True
# 8109b38a10                | 8109b38a10                | 0.9998	True
# 2801                      | 2801                      | 0.7859	True
# 8109f11a32                | 8109f11a32                | 0.9790	True
# 995c43a09                 | 995c43a09                 | 0.9992	True
# --------------------------------------------------------------------------------
# [2500/5000] Train loss: 0.00075, Valid loss: 0.17466, Elapsed_time: 2099.42014
# Current_accuracy : 90.775, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b38m51                | 8108b38m51                | 0.7445	True
# 995c44a10                 | 995c44a10                 | 0.3809	True
# 7002                      | 7002                      | 0.7848	True
# 7901                      | 4901                      | 0.9995	False
# 7202                      | 7202                      | 0.9990	True
# --------------------------------------------------------------------------------
# [2600/5000] Train loss: 0.00160, Valid loss: 0.16277, Elapsed_time: 2183.04657
# Current_accuracy : 90.174, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9901                      | 9901                      | 0.9962	True
# 994c51a20                 | 994c51a20                 | 0.9223	True
# 8093d41303                | 8093d41303                | 0.9999	True
# 983s11b50                 | 983s11b50                 | 0.9993	True
# 983s17t54                 | 983s17t54                 | 0.9679	True
# --------------------------------------------------------------------------------
# [2700/5000] Train loss: 0.00100, Valid loss: 0.18037, Elapsed_time: 2266.96042
# Current_accuracy : 90.441, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36t39                 | 995e36t39                 | 0.8656	True
# 3701                      | 3701                      | 0.9957	True
# 8603                      | 8603                      | 1.0000	True
# 9012f51a89                | 9012f51a89                | 0.8983	True
# 8052e81f56                | 8052e81f56                | 0.7728	True
# --------------------------------------------------------------------------------
# [2800/5000] Train loss: 0.00055, Valid loss: 0.17999, Elapsed_time: 2350.90818
# Current_accuracy : 90.575, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094b20617                | 8094b20617                | 0.7124	True
# 7002                      | 7002                      | 0.9983	True
# 7503                      | 7503                      | 0.7549	True
# 2604                      | 2604                      | 0.9759	True
# 995c43a09                 | 995c43a09                 | 0.8576	True
# --------------------------------------------------------------------------------
# [2900/5000] Train loss: 0.00095, Valid loss: 0.18238, Elapsed_time: 2434.58195
# Current_accuracy : 90.040, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4802                      | 4802                      | 0.9980	True
# 983e42f22                 | 983e41f22                 | 0.9960	False
# 0502                      | 0502                      | 0.9982	True
# 9012f51r04                | 9012f51r04                | 0.9840	True
# 8093f12732                | 8093f12732                | 0.7036	True
# --------------------------------------------------------------------------------
# [3000/5000] Train loss: 0.00080, Valid loss: 0.17865, Elapsed_time: 2518.21416
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b61d35                | 8108b61d35                | 0.4704	True
# 983h17b07                 | 983h17b07                 | 0.6453	True
# 8001                      | 6001                      | 0.9995	False
# 5203                      | 5203                      | 0.9956	True
# 983e41f22                 | 983e41f22                 | 0.9814	True
# --------------------------------------------------------------------------------
# [3100/5000] Train loss: 0.00069, Valid loss: 0.18347, Elapsed_time: 2601.93974
# Current_accuracy : 90.842, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093s11r0s                | 8093s11r05                | 0.9954	False
# 983s17t54                 | 983s17t54                 | 0.8819	True
# 8094s20b51                | 8094s20b51                | 0.9289	True
# 6803                      | 6803                      | 0.9997	True
# 4902                      | 4902                      | 0.6390	True
# --------------------------------------------------------------------------------
# [3200/5000] Train loss: 0.00082, Valid loss: 0.18522, Elapsed_time: 2686.77840
# Current_accuracy : 90.508, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995b17r09                 | 995b17r09                 | 0.9965	True
# 4401                      | 4401                      | 0.9996	True
# 7002                      | 7002                      | 0.9966	True
# 5001                      | 5001                      | 0.9991	True
# 5602                      | 5602                      | 0.5436	True
# --------------------------------------------------------------------------------
# [3300/5000] Train loss: 0.00060, Valid loss: 0.19448, Elapsed_time: 2770.34968
# Current_accuracy : 89.973, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e21435                 | 995z21435                 | 0.5906	False
# 9301                      | 9301                      | 0.9263	True
# 3702                      | 3702                      | 0.9972	True
# 6902                      | 6902                      | 0.9998	True
# 995b17r09                 | 995b17r09                 | 0.7322	True
# --------------------------------------------------------------------------------
# [3400/5000] Train loss: 0.00071, Valid loss: 0.19296, Elapsed_time: 2854.01583
# Current_accuracy : 90.775, Current_norm_ED  : 0.98
# Best_accuracy    : 90.842, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6604                      | 6604                      | 0.9999	True
# 7001                      | 7001                      | 0.9053	True
# 983e42b50                 | 983e42b50                 | 0.9977	True
# 983e42f22                 | 983e41f22                 | 0.8250	False
# 2404                      | 2404                      | 0.9718	True
# --------------------------------------------------------------------------------
# [3500/5000] Train loss: 0.00045, Valid loss: 0.19930, Elapsed_time: 2937.54080
# Current_accuracy : 90.909, Current_norm_ED  : 0.98
# Best_accuracy    : 90.909, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e24r04                 | 995e24r04                 | 0.9413	True
# 8108b40n68                | 8108b40n68                | 0.7515	True
# 8108f52b12                | 8108f52b12                | 0.9060	True
# 2701                      | 2701                      | 0.9999	True
# 8901                      | 8901                      | 0.8858	True
# --------------------------------------------------------------------------------
# [3600/5000] Train loss: 0.00061, Valid loss: 0.18353, Elapsed_time: 3021.34066
# Current_accuracy : 90.775, Current_norm_ED  : 0.98
# Best_accuracy    : 90.909, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094e28f43                | 8094e28f43                | 0.9682	True
# 6103                      | 6103                      | 1.0000	True
# 2402                      | 2402                      | 0.9995	True
# 0103                      | 0103                      | 1.0000	True
# 4902                      | 4902                      | 0.9993	True
# --------------------------------------------------------------------------------
# [3700/5000] Train loss: 0.00042, Valid loss: 0.19448, Elapsed_time: 3104.96548
# Current_accuracy : 90.374, Current_norm_ED  : 0.98
# Best_accuracy    : 90.909, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8053a81b14                | 8053a81b14                | 0.9580	True
# 4303                      | 4303                      | 0.8938	True
# 2801                      | 2801                      | 0.9863	True
# 8108sma28                 | 8108s17a28                | 0.5485	False
# 995b17r09                 | 995b17r09                 | 0.9939	True
# --------------------------------------------------------------------------------
# [3800/5000] Train loss: 0.00040, Valid loss: 0.20669, Elapsed_time: 3188.63692
# Current_accuracy : 89.973, Current_norm_ED  : 0.98
# Best_accuracy    : 90.909, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c32a14                 | 994c32a14                 | 0.8847	True
# 8094h21f43                | 8094h21f43                | 0.6832	True
# 8108s15g44                | 8108s15g44                | 0.5498	True
# 983s11r16                 | 983s11r16                 | 0.9989	True
# 995s16m10                 | 995s16m10                 | 0.9243	True
# --------------------------------------------------------------------------------
# [3900/5000] Train loss: 0.00080, Valid loss: 0.19011, Elapsed_time: 3272.09866
# Current_accuracy : 90.842, Current_norm_ED  : 0.98
# Best_accuracy    : 90.909, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7503                      | 7503                      | 0.9995	True
# 994c35a18                 | 994c35a18                 | 0.6633	True
# 1003                      | 1003                      | 0.9980	True
# 8108b15f15                | 8108b15f155               | 0.1665	False
# 5301                      | 5301                      | 0.9560	True
# --------------------------------------------------------------------------------
# [4000/5000] Train loss: 0.00045, Valid loss: 0.18407, Elapsed_time: 3355.69084
# Current_accuracy : 91.110, Current_norm_ED  : 0.98
# Best_accuracy    : 91.110, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7001                      | 7001                      | 0.9196	True
# 983e22b12                 | 983e22b12                 | 0.9946	True
# 4402                      | 4102                      | 0.9675	False
# 9012e32a19                | 9012e52a19                | 0.8898	False
# 8094t43j23                | 8094t43j23                | 0.7796	True
# --------------------------------------------------------------------------------
# [4100/5000] Train loss: 0.00031, Valid loss: 0.19738, Elapsed_time: 3439.61374
# Current_accuracy : 90.842, Current_norm_ED  : 0.98
# Best_accuracy    : 91.110, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012f51r04                | 9012f51r04                | 0.9759	True
# 6102                      | 6102                      | 0.9628	True
# 8108b51g50                | 8108b51g50                | 0.9479	True
# 8094g14v04                | 8094g14v04                | 0.8799	True
# 8109a32z64                | 8109a32z64                | 0.9078	True
# --------------------------------------------------------------------------------
# [4200/5000] Train loss: 0.00060, Valid loss: 0.20286, Elapsed_time: 3523.07128
# Current_accuracy : 91.176, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094h15b04                | 8094h15b04                | 0.7799	True
# 0401                      | 0401                      | 0.6180	True
# 994c50a20                 | 994c50a20                 | 0.8118	True
# 994c33a17                 | 991c33a17                 | 0.2471	False
# 2302                      | 2302                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4300/5000] Train loss: 0.00070, Valid loss: 0.19798, Elapsed_time: 3606.88734
# Current_accuracy : 91.176, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c32a14                 | 994c32a14                 | 0.6359	True
# 5602                      | 5602                      | 0.9317	True
# 9604                      | 9604                      | 0.9988	True
# 5804                      | 5804                      | 0.9984	True
# 8093f12732                | 8093f12732                | 0.5765	True
# --------------------------------------------------------------------------------
# [4400/5000] Train loss: 0.00033, Valid loss: 0.20321, Elapsed_time: 3690.48611
# Current_accuracy : 90.307, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9503                      | 9503                      | 0.9986	True
# 5401                      | 5401                      | 0.6564	True
# 1803                      | 1803                      | 1.0000	True
# 2801                      | 2801                      | 0.8278	True
# 994c35a02                 | 994c35a02                 | 0.9983	True
# --------------------------------------------------------------------------------
# [4500/5000] Train loss: 0.00034, Valid loss: 0.19928, Elapsed_time: 3774.15264
# Current_accuracy : 90.642, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094bs8f48                | 8094b53f48                | 0.7653	False
# 8094s20b51                | 8094s20b51                | 0.9750	True
# 8601                      | 8601                      | 0.9950	True
# 7002                      | 7002                      | 0.9215	True
# 983c33f23                 | 983c33f23                 | 0.9899	True
# --------------------------------------------------------------------------------
# [4600/5000] Train loss: 0.00022, Valid loss: 0.20255, Elapsed_time: 3857.58642
# Current_accuracy : 90.775, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f12j25                | 8093f12j25                | 0.9909	True
# 983s11r16                 | 983s11r16                 | 0.9993	True
# 0705                      | 0705                      | 0.9687	True
# 2801                      | 2801                      | 0.9802	True
# 9703                      | 9903                      | 0.9947	False
# --------------------------------------------------------------------------------
# [4700/5000] Train loss: 0.00028, Valid loss: 0.19964, Elapsed_time: 3941.04673
# Current_accuracy : 90.508, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8601                      | 8601                      | 0.9999	True
# 994a23r05                 | 994a23r05                 | 0.8098	True
# 8203                      | 8203                      | 1.0000	True
# 3702                      | 3702                      | 0.9999	True
# 994c35a02                 | 994c35a02                 | 0.9994	True
# --------------------------------------------------------------------------------
# [4800/5000] Train loss: 0.00034, Valid loss: 0.19398, Elapsed_time: 4024.72320
# Current_accuracy : 90.709, Current_norm_ED  : 0.98
# Best_accuracy    : 91.176, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983h17b07                 | 983h17b07                 | 0.8027	True
# 1803                      | 1803                      | 0.9892	True
# 6001                      | 6001                      | 0.2166	True
# 6004                      | 6004                      | 0.9999	True
# 5403                      | 5403                      | 0.7424	True
# --------------------------------------------------------------------------------
# [4900/5000] Train loss: 0.00037, Valid loss: 0.19993, Elapsed_time: 4108.18065
# Current_accuracy : 91.243, Current_norm_ED  : 0.98
# Best_accuracy    : 91.243, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109h13b19                | 8109h13b19                | 0.9230	True
# 995h13b08                 | 995h13b08                 | 0.9998	True
# 983n91b07                 | 983h91b07                 | 0.8061	False
# 5403                      | 5403                      | 0.9991	True
# 995h13b08                 | 995h13b08                 | 0.9998	True
# --------------------------------------------------------------------------------
# [5000/5000] Train loss: 0.00029, Valid loss: 0.20560, Elapsed_time: 4192.35881
# Current_accuracy : 90.441, Current_norm_ED  : 0.98
# Best_accuracy    : 91.243, Best_norm_ED     : 0.98
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995b14f39                 | 995b14f39                 | 0.8425	True
# 9012f41a09                | 9012f41a09                | 0.9909	True
# 5603                      | 5603                      | 0.9931	True
# 8094s13b57                | 8094s13b57                | 0.7771	True
# 0703                      | 0703                      | 0.9939	True
# --------------------------------------------------------------------------------
# end the training

# %% [markdown]
# # 5. None-ResNet-None-CTC.pth

# %%
args = argparse.Namespace(
    train_data = "../datasets/forTrainingData/train",
    valid_data = "../datasets/forTrainingData/val",
    select_data = "01-02-03",
    batch_ratio = "0.3-0.3-0.4",
    Transformation = "None",
    FeatureExtraction = "ResNet",
    SequenceModeling = "None",
    Prediction = "CTC",
    saved_model = "models/None-ResNet-None-CTC.pth",
    FT = True,
    manualSeed = 213,
    
    # Add arg for Training
    num_gpu = None,
    exp_name = None,
    workers = 0,
    batch_size = 192,
    data_filtering_off = None,
    imgH = 32,
    imgW = 100,
    num_iter = 5000,
    valInterval = 100, 
    adam = None,
    lr = 1,
    beta1 = 0.9,
    rho = 0.95,
    eps = 1e-8,
    grad_clip = 5,
    baiduCTC = None,
    total_data_usage_ratio = "1.0",
    batch_max_length = 25,
    rgb = None,
    sensitive = None,
    PAD = None,
    num_fiducial = 20,
    input_channel = 1,
    output_channel = 512,
    hidden_size = 256,
    character = '0123456789abcdefghijklmnopqrstuvwxyz'
    
)

# %%
opt = args

if not opt.exp_name:
    opt.exp_name = f'{opt.Transformation}-{opt.FeatureExtraction}-{opt.SequenceModeling}-{opt.Prediction}'
    opt.exp_name += f'-Seed{opt.manualSeed}'
    # print(opt.exp_name)

os.makedirs(f'./saved_models/{opt.exp_name}', exist_ok=True)

""" vocab / character number configuration """
if opt.sensitive:
    # opt.character += 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    opt.character = string.printable[:-6]  # same with ASTER setting (use 94 char).

""" Seed and GPU setting """
# print("Random Seed: ", opt.manualSeed)
random.seed(opt.manualSeed)
np.random.seed(opt.manualSeed)
torch.manual_seed(opt.manualSeed)
torch.cuda.manual_seed(opt.manualSeed)

cudnn.benchmark = True
cudnn.deterministic = True
opt.num_gpu = torch.cuda.device_count()
# print('device count', opt.num_gpu)
if opt.num_gpu > 1:
    print('------ Use multi-GPU setting ------')
    print('if you stuck too long time with multi-GPU setting, try to set --workers 0')
    # check multi-GPU issue https://github.com/clovaai/deep-text-recognition-benchmark/issues/1
    opt.workers = opt.workers * opt.num_gpu
    opt.batch_size = opt.batch_size * opt.num_gpu

    """ previous version
    print('To equlize batch stats to 1-GPU setting, the batch_size is multiplied with num_gpu and multiplied batch_size is ', opt.batch_size)
    opt.batch_size = opt.batch_size * opt.num_gpu
    print('To equalize the number of epochs to 1-GPU setting, num_iter is divided with num_gpu by default.')
    If you dont care about it, just commnet out these line.)
    opt.num_iter = int(opt.num_iter / opt.num_gpu)
    """

train(opt)
# Out:
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: ../datasets/forTrainingData/train
# opt.select_data: ['01', '02', '03']
# opt.batch_ratio: ['0.3', '0.3', '0.4']
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 01
# sub-directory:	/01	 num samples: 2989
# num total samples of 01: 2989 x 1.0 (total_data_usage_ratio) = 2989
# num samples of 01 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 02
# sub-directory:	/02	 num samples: 2872
# num total samples of 02: 2872 x 1.0 (total_data_usage_ratio) = 2872
# num samples of 02 per batch: 192 x 0.3 (batch_ratio) = 58
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/train	 dataset: 03
# sub-directory:	/03	 num samples: 119
# num total samples of 03: 119 x 1.0 (total_data_usage_ratio) = 119
# num samples of 03 per batch: 192 x 0.4 (batch_ratio) = 77
# --------------------------------------------------------------------------------
# Total_batch_size: 58+58+77 = 193
# --------------------------------------------------------------------------------
# dataset_root:    ../datasets/forTrainingData/val	 dataset: /
# sub-directory:	/01	 num samples: 747
# sub-directory:	/02	 num samples: 718
# sub-directory:	/03	 num samples: 31
# --------------------------------------------------------------------------------
# No Transformation module specified
# No SequenceModeling module specified
# model input parameters 32 100 20 1 512 256 37 25 None ResNet None CTC
# loading pretrained model from models/None-ResNet-None-CTC.pth
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): ResNet_FeatureExtractor(
#       (ConvNet): ResNet(
#         (conv0_1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv0_2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn0_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer1): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#         )
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (layer2): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (maxpool3): MaxPool2d(kernel_size=2, stride=(2, 1), padding=(0, 1), dilation=1, ceil_mode=False)
#         (layer3): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#             (downsample): Sequential(
#               (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             )
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (3): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (4): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv3): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (layer4): Sequential(
#           (0): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (1): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#           (2): BasicBlock(
#             (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (relu): ReLU(inplace=True)
#           )
#         )
#         (conv4_1): Conv2d(512, 512, kernel_size=(2, 2), stride=(2, 1), padding=(0, 1), bias=False)
#         (bn4_1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv4_2): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1), bias=False)
#         (bn4_2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (Prediction): Linear(in_features=512, out_features=37, bias=True)
#   )
# )
# Trainable params num :  44282885
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# train_data: ../datasets/forTrainingData/train
# valid_data: ../datasets/forTrainingData/val
# select_data: ['01', '02', '03']
# batch_ratio: ['0.3', '0.3', '0.4']
# Transformation: None
# FeatureExtraction: ResNet
# SequenceModeling: None
# Prediction: CTC
# saved_model: models/None-ResNet-None-CTC.pth
# FT: True
# manualSeed: 213
# num_gpu: 1
# exp_name: None-ResNet-None-CTC-Seed213
# workers: 0
# batch_size: 193
# data_filtering_off: None
# imgH: 32
# imgW: 100
# num_iter: 5000
# valInterval: 100
# adam: None
# lr: 1
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# baiduCTC: None
# total_data_usage_ratio: 1.0
# batch_max_length: 25
# rgb: None
# sensitive: None
# PAD: None
# num_fiducial: 20
# input_channel: 1
# output_channel: 512
# hidden_size: 256
# character: 0123456789abcdefghijklmnopqrstuvwxyz
# num_class: 37
# ---------------------------------------
# [1/5000] Train loss: 17.70298, Valid loss: 4.86960, Elapsed_time: 0.78249
# Current_accuracy : 3.409, Current_norm_ED  : 0.22
# Best_accuracy    : 3.409, Best_norm_ED     : 0.22
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b38m51                | s0bbsm                    | 0.0002	False
# 6501                      | 6501                      | 0.2493	True
# 995b13g49                 | asbeghd                   | 0.0007	False
# 8108b23d2                 | s08b2dd                   | 0.0019	False
# 995m31b07                 | tcoikon                   | 0.0006	False
# --------------------------------------------------------------------------------
# [100/5000] Train loss: 1.01397, Valid loss: 0.23527, Elapsed_time: 75.75139
# Current_accuracy : 74.332, Current_norm_ED  : 0.95
# Best_accuracy    : 74.332, Best_norm_ED     : 0.95
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 2801                      | 2801                      | 0.9885	True
# 0004                      | 00063                     | 0.0697	False
# 2003                      | 2003                      | 0.9291	True
# 8603                      | 8603                      | 0.9595	True
# 2703                      | 2703                      | 0.9886	True
# --------------------------------------------------------------------------------
# [200/5000] Train loss: 0.10082, Valid loss: 0.17280, Elapsed_time: 151.56580
# Current_accuracy : 83.356, Current_norm_ED  : 0.97
# Best_accuracy    : 83.356, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36t39                 | 995e36t39                 | 0.5136	True
# 7002                      | 7002                      | 0.8624	True
# 995e33a12                 | 995e33a12                 | 0.5074	True
# 5705                      | 5706                      | 0.7385	False
# 3701                      | 3701                      | 0.9850	True
# --------------------------------------------------------------------------------
# [300/5000] Train loss: 0.05301, Valid loss: 0.16616, Elapsed_time: 227.32927
# Current_accuracy : 86.029, Current_norm_ED  : 0.97
# Best_accuracy    : 86.029, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8601                      | 8601                      | 0.8601	True
# 8094h13b12                | 8094h13b12                | 0.8188	True
# 995e35318                 | 995e35318                 | 0.9452	True
# 9012z31g10                | 9012e31e10                | 0.2225	False
# 8108f51f85                | 8108f51f85                | 0.3108	True
# --------------------------------------------------------------------------------
# [400/5000] Train loss: 0.03311, Valid loss: 0.16719, Elapsed_time: 303.02757
# Current_accuracy : 86.430, Current_norm_ED  : 0.97
# Best_accuracy    : 86.430, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109e51h38                | 8109e51h38                | 0.8935	True
# 9901                      | 9901                      | 0.9996	True
# 8108b62623                | 8108b62g23                | 0.4154	False
# 0705                      | 0705                      | 0.9691	True
# 3901                      | 3901                      | 0.9968	True
# --------------------------------------------------------------------------------
# [500/5000] Train loss: 0.02344, Valid loss: 0.17334, Elapsed_time: 378.77112
# Current_accuracy : 87.366, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109a31g66                | 8109a31g66                | 0.9299	True
# 3704                      | 8704                      | 0.5702	False
# 4802                      | 4802                      | 0.9996	True
# 7002                      | 7002                      | 0.9054	True
# 995c42a18                 | 995c42a18                 | 0.8090	True
# --------------------------------------------------------------------------------
# [600/5000] Train loss: 0.01574, Valid loss: 0.18006, Elapsed_time: 454.48807
# Current_accuracy : 86.631, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5602                      | 5602                      | 0.9949	True
# 995e36t39                 | 995e36t39                 | 0.9028	True
# 1103                      | 1103                      | 0.9996	True
# 4301                      | 4301                      | 0.9609	True
# 6402                      | 6402                      | 0.9588	True
# --------------------------------------------------------------------------------
# [700/5000] Train loss: 0.01158, Valid loss: 0.18620, Elapsed_time: 529.60831
# Current_accuracy : 86.765, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 983s17t54                 | 983s17t54                 | 0.6482	True
# 6702                      | 6702                      | 0.5969	True
# 8093d33f25                | 8093d33f25                | 0.6000	True
# 983e32f81                 | 983e32f81                 | 0.8437	True
# 5701                      | 5001                      | 0.5111	False
# --------------------------------------------------------------------------------
# [800/5000] Train loss: 0.00833, Valid loss: 0.19433, Elapsed_time: 604.57942
# Current_accuracy : 86.765, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6303                      | 6303                      | 0.9962	True
# 4401                      | 4401                      | 0.9906	True
# 995e36317                 | 995e35317                 | 0.3706	False
# 4502                      | 4502                      | 0.8538	True
# 2801                      | 2801                      | 0.9999	True
# --------------------------------------------------------------------------------
# [900/5000] Train loss: 0.00605, Valid loss: 0.20117, Elapsed_time: 679.80821
# Current_accuracy : 86.832, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109b42a11                | 8109b42a11                | 0.8612	True
# 8094s20b51                | 8094s20b51                | 0.4162	True
# 8108b64312                | 8108b64312                | 0.2270	True
# 8603                      | 8603                      | 0.9963	True
# 9401                      | 9401                      | 0.4783	True
# --------------------------------------------------------------------------------
# [1000/5000] Train loss: 0.00457, Valid loss: 0.20620, Elapsed_time: 755.05522
# Current_accuracy : 86.832, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5902                      | 5902                      | 0.7055	True
# 8601                      | 8601                      | 1.0000	True
# 994e43t09                 | 994e43t09                 | 0.7203	True
# 9301                      | 9701                      | 0.6904	False
# 8093a21307                | 8093a21307                | 0.6841	True
# --------------------------------------------------------------------------------
# [1100/5000] Train loss: 0.00329, Valid loss: 0.21207, Elapsed_time: 830.08114
# Current_accuracy : 86.832, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5501                      | 5501                      | 0.9965	True
# 3603                      | 3603                      | 0.9995	True
# 995e36t39                 | 995e36t39                 | 0.7483	True
# 4802                      | 4802                      | 0.6202	True
# 2901                      | 2901                      | 1.0000	True
# --------------------------------------------------------------------------------
# [1200/5000] Train loss: 0.00261, Valid loss: 0.22085, Elapsed_time: 905.21714
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e21f64                 | 995e21f64                 | 0.9857	True
# 4901                      | 4901                      | 0.7143	True
# 1203                      | 1203                      | 0.7169	True
# 2703                      | 7703                      | 0.6404	False
# 0101                      | 0101                      | 0.9995	True
# --------------------------------------------------------------------------------
# [1300/5000] Train loss: 0.00185, Valid loss: 0.22555, Elapsed_time: 980.40714
# Current_accuracy : 86.765, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8501                      | 8501                      | 0.9994	True
# 3902                      | 3902                      | 0.9813	True
# 8094s13b53                | 8094s13b53                | 0.5760	True
# 8094s20b51                | 8094s20b51                | 0.5694	True
# 2801                      | 2801                      | 0.6393	True
# --------------------------------------------------------------------------------
# [1400/5000] Train loss: 0.00154, Valid loss: 0.23138, Elapsed_time: 1056.64845
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6702                      | 6702                      | 0.9997	True
# 983s16a39                 | 983s16a39                 | 0.5926	True
# 994a23r05                 | 994a23r05                 | 0.4748	True
# 3702                      | 3702                      | 0.9954	True
# 3001                      | 3001                      | 0.9976	True
# --------------------------------------------------------------------------------
# [1500/5000] Train loss: 0.00128, Valid loss: 0.23687, Elapsed_time: 1131.97840
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8093f41a05                | 8093f01a055               | 0.4292	False
# 8803                      | 8803                      | 0.9913	True
# 983e21g11                 | 983e21g11                 | 0.9832	True
# 4801                      | 4801                      | 1.0000	True
# 995s16m10                 | 995s16m10                 | 0.8233	True
# --------------------------------------------------------------------------------
# [1600/5000] Train loss: 0.00116, Valid loss: 0.23865, Elapsed_time: 1207.32857
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1102                      | 1102                      | 0.6354	True
# 3603                      | 3603                      | 1.0000	True
# 983s16a39                 | 983s16a39                 | 0.6421	True
# 6803                      | 6803                      | 1.0000	True
# 7001                      | 7001                      | 0.9993	True
# --------------------------------------------------------------------------------
# [1700/5000] Train loss: 0.00166, Valid loss: 0.24666, Elapsed_time: 1282.74410
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7601                      | 7601                      | 0.9999	True
# 7503                      | 7503                      | 0.9653	True
# 3603                      | 3603                      | 0.9990	True
# 995e36317                 | 995e35317                 | 0.9758	False
# 8108f41310                | 8108f41310                | 0.7350	True
# --------------------------------------------------------------------------------
# [1800/5000] Train loss: 0.00073, Valid loss: 0.25173, Elapsed_time: 1358.23141
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0001                      | 0001                      | 1.0000	True
# 983s24j58                 | 983s24u58                 | 0.3084	False
# 994e43t09                 | 994e43t09                 | 0.5982	True
# 5801                      | 5801                      | 0.5551	True
# 983s11b41                 | 983s11b41                 | 0.7696	True
# --------------------------------------------------------------------------------
# [1900/5000] Train loss: 0.00068, Valid loss: 0.25571, Elapsed_time: 1433.46390
# Current_accuracy : 86.965, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1301                      | 1301                      | 0.9685	True
# 4601                      | 4601                      | 0.9534	True
# 4904                      | 4904                      | 0.9999	True
# 8093e25b007               | 8093e25b07                | 0.4339	False
# 983e41f22                 | 983e41f22                 | 0.6091	True
# --------------------------------------------------------------------------------
# [2000/5000] Train loss: 0.00058, Valid loss: 0.25304, Elapsed_time: 1508.65237
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094e12r07                | 8094e12r07                | 0.9999	True
# 9301                      | 9301                      | 0.9870	True
# 8094h21f39                | 8094h21f39                | 0.6683	True
# 7002                      | 7002                      | 0.9995	True
# 995b17r09                 | 995b17r09                 | 0.8590	True
# --------------------------------------------------------------------------------
# [2100/5000] Train loss: 0.00045, Valid loss: 0.26048, Elapsed_time: 1583.75995
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012f11a20                | 9012f11a20                | 0.4558	True
# 8109t21b16                | 8109t21b16                | 0.9945	True
# 8603                      | 8603                      | 0.9934	True
# 4802                      | 4802                      | 0.9730	True
# 2102                      | 2702                      | 0.5268	False
# --------------------------------------------------------------------------------
# [2200/5000] Train loss: 0.00041, Valid loss: 0.26421, Elapsed_time: 1658.82927
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4202                      | 4202                      | 0.9466	True
# 3702                      | 3702                      | 0.9981	True
# 6301                      | 6301                      | 1.0000	True
# 8094d15a01                | 8094d15a01                | 0.8742	True
# 6602                      | 6602                      | 0.9996	True
# --------------------------------------------------------------------------------
# [2300/5000] Train loss: 0.00036, Valid loss: 0.26347, Elapsed_time: 1734.15517
# Current_accuracy : 87.233, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8501                      | 8501                      | 0.9998	True
# 3603                      | 3603                      | 0.9998	True
# 8093f12j25                | 8093f12j25                | 0.7877	True
# 1701                      | 1701                      | 0.9999	True
# 8601                      | 8601                      | 1.0000	True
# --------------------------------------------------------------------------------
# [2400/5000] Train loss: 0.00033, Valid loss: 0.26597, Elapsed_time: 1809.40051
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8109e82308                | 8109e32308                | 0.3801	False
# 8601                      | 8601                      | 0.9986	True
# 9401                      | 9401                      | 0.9976	True
# b094d11a11                | 8094d11a11                | 0.9386	False
# 8201                      | 8201                      | 0.9701	True
# --------------------------------------------------------------------------------
# [2500/5000] Train loss: 0.00029, Valid loss: 0.28997, Elapsed_time: 1884.52628
# Current_accuracy : 87.099, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012z31g10                | 9012e31e10                | 0.8075	False
# 995b17r09                 | 995b17r09                 | 0.5157	True
# 5903                      | 5903                      | 0.9985	True
# 4001                      | 4001                      | 0.9883	True
# 995e21b59                 | 995e21b59                 | 0.9533	True
# --------------------------------------------------------------------------------
# [2600/5000] Train loss: 0.00025, Valid loss: 0.26640, Elapsed_time: 1959.78355
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9102                      | 9102                      | 0.9493	True
# 3001                      | 3001                      | 1.0000	True
# 2701                      | 2701                      | 0.9997	True
# 4401                      | 4401                      | 0.7407	True
# 8093d41303                | 8033d41303                | 0.4192	False
# --------------------------------------------------------------------------------
# [2700/5000] Train loss: 0.00023, Valid loss: 0.27705, Elapsed_time: 2035.10538
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094s13b57                | 8094s13b57                | 0.9913	True
# 8094h15b04                | 8094h15b04                | 0.9979	True
# 9904                      | 5904                      | 0.3873	False
# 995c44a09                 | 995c44a09                 | 0.5677	True
# 8108d16b16                | 8108d16b16                | 0.4421	True
# --------------------------------------------------------------------------------
# [2800/5000] Train loss: 0.00023, Valid loss: 0.29129, Elapsed_time: 2110.30831
# Current_accuracy : 87.233, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 0904                      | 0904                      | 0.9992	True
# 983e42h78                 | 983e42h78                 | 0.9990	True
# 8093f12732                | 8093f12732                | 0.9426	True
# 6501                      | 6501                      | 0.9496	True
# 8109b26a94                | 8109b36a94                | 0.9977	False
# --------------------------------------------------------------------------------
# [2900/5000] Train loss: 0.00019, Valid loss: 0.27525, Elapsed_time: 2185.64436
# Current_accuracy : 87.099, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7901                      | 7901                      | 1.0000	True
# 9502                      | 9502                      | 0.5992	True
# 4001                      | 4001                      | 1.0000	True
# 8802                      | 8802                      | 0.8957	True
# 9012e31b68                | 9012e31b68                | 0.9999	True
# --------------------------------------------------------------------------------
# [3000/5000] Train loss: 0.00017, Valid loss: 0.27735, Elapsed_time: 2260.95931
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8601                      | 8601                      | 0.9999	True
# 9604                      | 9604                      | 0.9998	True
# 995c44a09                 | 995c44a09                 | 0.6472	True
# 5801                      | 5801                      | 0.6381	True
# 5903                      | 5903                      | 0.9998	True
# --------------------------------------------------------------------------------
# [3100/5000] Train loss: 0.00018, Valid loss: 0.27905, Elapsed_time: 2336.27106
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8108b61307                | 8108b61307                | 0.9060	True
# 995h31b06                 | 995h31b06                 | 0.9699	True
# 3002                      | 3002                      | 1.0000	True
# 7702                      | 7702                      | 0.9537	True
# 995e34a16                 | 995e34a16                 | 0.8426	True
# --------------------------------------------------------------------------------
# [3200/5000] Train loss: 0.00018, Valid loss: 0.27904, Elapsed_time: 2411.45955
# Current_accuracy : 87.099, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9801                      | 9801                      | 1.0000	True
# 0204                      | 0204                      | 1.0000	True
# 995e36t39                 | 995e36t39                 | 0.8263	True
# 0103                      | 0103                      | 0.9985	True
# 3701                      | 3701                      | 0.5604	True
# --------------------------------------------------------------------------------
# [3300/5000] Train loss: 0.00015, Valid loss: 0.28143, Elapsed_time: 2486.61872
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c50a20                 | 994c50a20                 | 0.7754	True
# 5003                      | 503                       | 0.9007	False
# 5302                      | 5302                      | 0.9971	True
# 5302                      | 5302                      | 0.9999	True
# 8109e82b52                | 8109e82b52                | 0.2772	True
# --------------------------------------------------------------------------------
# [3400/5000] Train loss: 0.00015, Valid loss: 0.28843, Elapsed_time: 2561.68199
# Current_accuracy : 87.366, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094s13b57                | 8094s13b57                | 0.8061	True
# 5002                      | 5002                      | 0.9817	True
# 9012f21a19                | 9012f21a19                | 0.9999	True
# 5302                      | 5302                      | 0.9961	True
# 7501                      | 7501                      | 0.8506	True
# --------------------------------------------------------------------------------
# [3500/5000] Train loss: 0.00015, Valid loss: 0.28401, Elapsed_time: 2637.06022
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4901                      | 4901                      | 0.6762	True
# 8108f41b33                | 8108f41b33                | 0.7559	True
# 8108f51f85                | 8108f51f85                | 0.6611	True
# 8094h12b20                | 8094h12b20                | 0.9985	True
# 8802                      | 8802                      | 0.9988	True
# --------------------------------------------------------------------------------
# [3600/5000] Train loss: 0.00012, Valid loss: 0.28611, Elapsed_time: 2712.17615
# Current_accuracy : 87.233, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9012a31a46                | 9012a31ay6                | 0.3113	False
# 2801                      | 2801                      | 1.0000	True
# 5101                      | 5101                      | 1.0000	True
# 5001                      | 5001                      | 0.9150	True
# 1604                      | 1604                      | 0.9973	True
# --------------------------------------------------------------------------------
# [3700/5000] Train loss: 0.00015, Valid loss: 0.28374, Elapsed_time: 2787.25535
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 994c50a20                 | 994c50a20                 | 0.8581	True
# 9012f51r04                | 9012f51r04                | 0.9981	True
# 8109b38a10                | 8109b38a10                | 0.9847	True
# 995c44a07                 | 995c44a07                 | 0.9424	True
# 983s24j60                 | 983s24j60                 | 0.8069	True
# --------------------------------------------------------------------------------
# [3800/5000] Train loss: 0.00012, Valid loss: 0.28177, Elapsed_time: 2862.58013
# Current_accuracy : 87.299, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 9701                      | 9701                      | 1.0000	True
# 9801                      | 9801                      | 1.0000	True
# 995e35318                 | 995e35318                 | 0.9999	True
# 0705                      | 0705                      | 0.9991	True
# 9012e32a19                | 9012e32a19                | 0.9592	True
# --------------------------------------------------------------------------------
# [3900/5000] Train loss: 0.00010, Valid loss: 0.28825, Elapsed_time: 2937.84835
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 5301                      | 5301                      | 1.0000	True
# 7103                      | 7103                      | 0.9999	True
# 995s16m10                 | 995s16m10                 | 0.6756	True
# 5001                      | 5001                      | 1.0000	True
# 8108f41310                | 8108f41310                | 0.9265	True
# --------------------------------------------------------------------------------
# [4000/5000] Train loss: 0.00060, Valid loss: 0.28590, Elapsed_time: 3013.04254
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1202                      | 1202                      | 0.6772	True
# 983n91b07                 | 983h91b07                 | 0.9973	False
# 6501                      | 6501                      | 0.9709	True
# 8108b61307                | 8108b61307                | 0.6871	True
# 8109b42g26                | 8109b42g26                | 0.8236	True
# --------------------------------------------------------------------------------
# [4100/5000] Train loss: 0.00016, Valid loss: 0.28917, Elapsed_time: 3088.52119
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 3601                      | 3601                      | 1.0000	True
# 9012f51r04                | 9012f51r04                | 1.0000	True
# 8109b39m73                | 8109b39m73                | 0.4599	True
# 4901                      | 4901                      | 0.9615	True
# 4802                      | 4802                      | 0.8609	True
# --------------------------------------------------------------------------------
# [4200/5000] Train loss: 0.00013, Valid loss: 0.29233, Elapsed_time: 3163.82502
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 1301                      | 1301                      | 0.6901	True
# 8108b15f15                | 8108b15f153               | 0.5596	False
# 8201                      | 8201                      | 0.9953	True
# 8093b12f24                | 8093b12f24                | 0.7028	True
# 3401                      | 3401                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4300/5000] Train loss: 0.00012, Valid loss: 0.28864, Elapsed_time: 3239.13570
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 4901                      | 4901                      | 0.9039	True
# 5602                      | 5602                      | 0.9986	True
# 983b15a08                 | 983b15a08                 | 0.9819	True
# 983e42h78                 | 983e42h78                 | 0.9996	True
# 983e42730                 | 983e42730                 | 0.9797	True
# --------------------------------------------------------------------------------
# [4400/5000] Train loss: 0.00011, Valid loss: 0.29360, Elapsed_time: 3314.19112
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 6803                      | 6803                      | 1.0000	True
# 4303                      | 4303                      | 0.9209	True
# 8109b38a10                | 8109b38a10                | 0.9995	True
# 1001                      | 1001                      | 0.9711	True
# 983c33f20                 | 983c33e20                 | 0.7782	False
# --------------------------------------------------------------------------------
# [4500/5000] Train loss: 0.00014, Valid loss: 0.29169, Elapsed_time: 3389.36756
# Current_accuracy : 87.032, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 7002                      | 7002                      | 0.7909	True
# 6803                      | 6803                      | 0.9998	True
# 6201                      | 6201                      | 0.5222	True
# 4304                      | 4304                      | 0.9937	True
# 6501                      | 6501                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4600/5000] Train loss: 0.00010, Valid loss: 0.29531, Elapsed_time: 3464.72512
# Current_accuracy : 87.099, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36317                 | 995e35317                 | 0.4852	False
# 7002                      | 7002                      | 0.9716	True
# 9012e32a19                | 9012e32a19                | 0.9925	True
# 8094s20b51                | 8094s20b51                | 0.8923	True
# 0103                      | 0103                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4700/5000] Train loss: 0.00014, Valid loss: 0.29832, Elapsed_time: 3539.83463
# Current_accuracy : 87.233, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8802                      | 8802                      | 0.9979	True
# 9012f41a09                | 9012f41r9                 | 0.7873	False
# 8094b58f48                | 8094b58f48                | 0.4337	True
# 8094s17a01                | 8094s17a01                | 0.8252	True
# 983s24j58                 | 983s24u57                 | 0.3211	False
# --------------------------------------------------------------------------------
# [4800/5000] Train loss: 0.00015, Valid loss: 0.30046, Elapsed_time: 3615.14696
# Current_accuracy : 87.166, Current_norm_ED  : 0.97
# Best_accuracy    : 87.366, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e36t39                 | 995e36t39                 | 0.9959	True
# 7001                      | 7001                      | 0.9997	True
# 5602                      | 5602                      | 1.0000	True
# 8108f31322                | 8108f31322                | 0.9856	True
# 4901                      | 4901                      | 1.0000	True
# --------------------------------------------------------------------------------
# [4900/5000] Train loss: 0.00008, Valid loss: 0.31808, Elapsed_time: 3690.31666
# Current_accuracy : 87.433, Current_norm_ED  : 0.97
# Best_accuracy    : 87.433, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 8094d11a11                | 809ad11a11                | 0.7309	False
# 9301                      | 9701                      | 0.9242	False
# 9401                      | 9401                      | 0.9990	True
# 6902                      | 6902                      | 0.9970	True
# 6501                      | 6501                      | 1.0000	True
# --------------------------------------------------------------------------------
# [5000/5000] Train loss: 0.00012, Valid loss: 0.29790, Elapsed_time: 3766.20593
# Current_accuracy : 86.765, Current_norm_ED  : 0.97
# Best_accuracy    : 87.433, Best_norm_ED     : 0.97
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# 995e33a12                 | 995e33a12                 | 0.8834	True
# 0001                      | 0001                      | 1.0000	True
# 8108f41310                | 8108f41310                | 0.5938	True
# 995e36t39                 | 995e36t39                 | 0.9967	True
# 5801                      | 5801                      | 0.6714	True
# --------------------------------------------------------------------------------
# end the training
